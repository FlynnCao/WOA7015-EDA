# %% [markdown]
# # Step0: Import packages and preparing the data
# Carefully make sure you `data_dir` can get the right RESP and HEA data!

# %%
# !pip install wfdb
import os
import numpy as np
import matplotlib.pyplot as plt
import wfdb # read Physionet/picsdb file format
import xlrd
from scipy.signal import welch, butter, filtfilt
from wfdb import processing
from numba import jit


data_dir = "E:\\jupter-repos\\picsdb\\1.0.0"
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: wfdb in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy<2.0.0,>=1.10.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (1.23.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.2.2 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (3.6.2)
# Requirement already satisfied: requests<3.0.0,>=2.8.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (2.27.1)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (1.5.2)
# Requirement already satisfied: SoundFile<0.12.0,>=0.10.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (0.11.0)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from wfdb) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->wfdb) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.0.0,>=1.0.0->wfdb) (2022.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.8.1->wfdb) (1.26.9)
# Requirement already satisfied: cffi>=1.0 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from SoundFile<0.12.0,>=0.10.0->wfdb) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->SoundFile<0.12.0,>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\flynn\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.2.2->wfdb) (1.16.0)

# %%
# outside functions
def bp_filter(x, fs, f_lo, f_hi):
    """
    implement digital band-pass filter
    6-th order Butterworth filter, zero-phase implementation
    """
    f_Ny = fs/2
    b_lo = f_lo / f_Ny
    b_hi = f_hi / f_Ny
    # filter parameters
    p_lp = {'N': 6, 'Wn': b_hi, 'btype': 'lowpass',
            'analog': False, 'output': 'ba'}
    p_hp = {'N': 6, 'Wn': b_lo, 'btype': 'highpass',
            'analog': False, 'output': 'ba'}
    bp_b1, bp_a1 = butter(**p_lp)
    bp_b2, bp_a2 = butter(**p_hp)
    x_filt = filtfilt(bp_b1, bp_a1, x, axis=0)
    x_filt = filtfilt(bp_b2, bp_a2, x_filt, axis=0)
    return x_filt


def interval_stats(ts, dt):
    """
    Inputs:
    ts, array of time points, e.g. local maxima of oscillating curve
    dt: sampling interval in seconds
    """
    dts = np.diff(ts)*dt
    mn = dts.min()
    mx = dts.max()
    mu = dts.mean()
    mu_freq = 1/mu
    sd = dts.std()
    q25 = np.percentile(dts, 25)
    q75 = np.percentile(dts, 75)
    print(f"Interval stats (n={len(dts):d}) :")
    print(f"min: {mn:.2f} sec")
    print(f"max: {mx:.2f} sec")
    print(f"mean: {mu:.2f} sec (= {mu_freq:.2f} Hz)")
    print(f"std: {sd:.2f} sec")
    print(f"q25: {q25:.2f} sec")
    print(f"q75: {q75:.2f} sec")
    return dts


def load_segments(filename, verbose=True):
    """
    Load filter and threshold parameters from .xlsx file
    dictionary of subjects and segments, processing parameters
    """
    w = xlrd.open_workbook(filename)
    R = w.sheet_by_name("Sheet1")
    #print(f"Excel document: rows = {R.nrows:d}, cols = {R.ncols:d}")
    # get number of segments
    n_segments = R.nrows-1
    segments = {}
    subj_set = set()  # count unique subject IDs
    for i in range(1, n_segments+1):
        a, b = str(R.cell_value(i, 0)).split(".")
        i_subj = int(a)
        i_seg = int(b)
        if verbose:
            print(f"\nsubject: {i_subj:d}, segment: {i_seg:d}")
        key_subj = f"infant{i_subj:d}"
        key_seg = f"segment{i_seg:d}"
        if i_subj not in subj_set:
            # start new sub-dictionary for each subject
            segments[key_subj] = {}
        segments[key_subj][key_seg] = {}
        subj_set.add(i_subj)
        # segment start (on) and stop (off) indices
        segments[key_subj][key_seg]['on'] = int(R.cell_value(i, 1))
        segments[key_subj][key_seg]['off'] = int(R.cell_value(i, 2))
        # ECG band-pass frequencies
        segments[key_subj][key_seg]['freq_lo_ecg'] = float(R.cell_value(i, 3))
        segments[key_subj][key_seg]['freq_hi_ecg'] = float(R.cell_value(i, 4))
        # RESP band-pass frequencies
        segments[key_subj][key_seg]['freq_lo_resp'] = float(R.cell_value(i, 5))
        segments[key_subj][key_seg]['freq_hi_resp'] = float(R.cell_value(i, 6))
        # ECG & RESP thresholds
        segments[key_subj][key_seg]['thr_ecg'] = float(R.cell_value(i, 7))
        segments[key_subj][key_seg]['thr_resp'] = float(R.cell_value(i, 8))
        # maximum peak-to-peak frequency for ECG & RESP
        segments[key_subj][key_seg]['f_max_ecg'] = float(R.cell_value(i, 9))
        segments[key_subj][key_seg]['f_max_resp'] = float(R.cell_value(i, 10))
        if verbose:
            print(f"on: {segments[key_subj][key_seg]['on']:d}")
            print(f"off: {segments[key_subj][key_seg]['off']:d}")
            print(
                f"freq_lo_ecg: {segments[key_subj][key_seg]['freq_lo_ecg']:.3f}")
            print(
                f"freq_hi_ecg: {segments[key_subj][key_seg]['freq_hi_ecg']:.3f}")
            print(
                f"freq_lo_resp: {segments[key_subj][key_seg]['freq_lo_resp']:.3f}")
            print(
                f"freq_hi_resp: {segments[key_subj][key_seg]['freq_hi_resp']:.3f}")
            print(f"thr_ecg: {segments[key_subj][key_seg]['thr_ecg']:.3f}")
            print(f"thr_resp: {segments[key_subj][key_seg]['thr_resp']:.3f}")
            print(f"f_max_ecg: {segments[key_subj][key_seg]['f_max_ecg']:.3f}")
            print(
                f"f_max_resp: {segments[key_subj][key_seg]['f_max_resp']:.3f}")
    return segments


def load_waveforms(data_dir, infant_index, verbose=True):
    """
    load ECG/RESP waveforms, return as arrays, return sampling freqs
    """
    file_ecg = f"infant{infant_index:d}_ecg"
    file_resp = f"infant{infant_index:d}_resp"
    record_ecg = wfdb.rdrecord(os.path.join(data_dir, file_ecg))
    record_resp = wfdb.rdrecord(os.path.join(data_dir, file_resp))
    d_ecg = record_ecg.__dict__
    d_resp = record_resp.__dict__
    fs_ecg = d_ecg['fs']  # ECG sampling rate in Hz
    fs_resp = d_resp['fs']  # RESP sampling rate in Hz
    x_ecg = d_ecg['p_signal'].ravel()
    x_resp = d_resp['p_signal'].ravel()
    if verbose:
        print("Loading ECG file: ", file_ecg)
        print("Loading RESP file: ", file_resp)
        #print("ECG record: ", d_ecg['record_name'])
        #print("number of signals: ", d_ecg['n_sig'])
        #print("sampling frequency: ", d_ecg['fs'], "Hz")
        #print("Number of samples: ", d_ecg['sig_len'])
        #print("Signal name: ", d_ecg['sig_name'])
        #print("RESP record: ", d_resp['record_name'])
        #print("number of signals: ", d_resp['n_sig'])
        #print("sampling frequency: ", d_resp['fs'], "Hz")
        #print("Number of samples: ", d_resp['sig_len'])
        #print("Signal name: ", d_resp['sig_name'])
        print("ECG sampling frequency: ", fs_ecg, " Hz")
        print("RESP sampling frequency: ", fs_resp, " Hz")
    return x_ecg, x_resp, fs_ecg, fs_resp


def locmax(x):
    p = 1 + np.where(np.diff(np.sign(np.diff(x))) == -2)[0]
    return p


def p_hat(x, n_bins=50, method='histogram'):
    """
    Histogram / kernel estimate of p(r)
    method = 'histogram', 'kernel'
    """
    x_max = x.max()
    if method == 'histogram':
        x_bins = np.linspace(0, x_max, num=n_bins, endpoint=True)
        p_hat, _ = np.histogram(x, bins=x_bins, density=True)
        p_hat /= p_hat.sum()
        x_ax = 0.5*(x_bins[:-1] + x_bins[1:])  # correct n_bins+1 issue
    if method == 'kernel':
        # gaussian, tophat, epanechnikov, exponential, linear, cosine
        kde = KernelDensity(bandwidth=0.25, kernel='epanechnikov')
        kde.fit(x[:, None])
        x_ax = np.linspace(0, x_max, num=n_bins, endpoint=True)
        log_p = kde.score_samples(x_ax[:, None])
        p_hat = np.exp(log_p)
        p_hat /= p_hat.sum()
    return x_ax, p_hat


def poincare_plot(I, I_min=None, I_max=None, doplot=False):
    """
    Construct Poincaré plot, get principal axes of main cloud
    Arguments:
        I: list of interval lengths (durations of respiratory cycles)
    Returns:
        sd1, sd2: length of principal axes
    """
    #print("\n[+] Poincare plot")
    if not I_min:
        I_min = I.min()
    if not I_max:
        I_max = I.max()
    #I_min, I_max = I.min(), I.max()
    #I_min, I_max = 0, 200
    I = I[I >= I_min]
    I = I[I <= I_max]
    nI = len(I)
    print("[+] Poincare plot function:")
    print(f"mean: {I.mean():.2f}, std: {I.std():.2f}")
    x, y = I[:-1], I[1:]
    data = np.vstack((x, y))
    x_m = x.mean()
    y_m = y.mean()
    #print(f"\tnumerical means: {x_m:.3f}, {y_m:.3f}")
    C = np.cov(data)
    #print(f"\tcov. matrix C: \n", C)
    # print("\tcov. matrix C: ", f"\n\t\t{C[0,0]:.3f}, {C[0,1]:.3f}", \
    # f"\n\t\t{C[1,0]:.3f}, {C[1,1]:.3f}")

    # method 1: manual PCA (eigen-analysis of data cov matrix)
    #print("\nMethod-1: manual PCA (diagon. cov. matrix)")
    L, V = np.linalg.eig(C)
    l0, l1 = L[0], L[1]
    v0, v1 = V[:, 0], V[:, 1]
    del L, V
    #print(f"\tC eigenvalues: l0 = {l0:.3f}, l1 = {l1:.3f}")
    #print("\tC eigenvectors: ")
    #print("\tv0 = ", np.round(v0,3))
    #print("\tv1 = ", np.round(v1,3))
    #print("\tcheck orthogonality: <v0, v1> = ", np.dot(v0, v1))

    # order eigenvalue magnitudes (small, large)
    # if (l0 > l1):
    #    l0, l1 = l1, l0
    #    v0, v1 = v1, v0

    # test vectors
    v_diag = np.array([1, 1])/np.sqrt(2)  # along main diagonal (identity, x=y)
    v_codiag = np.array([-1, 1])/np.sqrt(2)  # perpendicular to diagonal
    # test eigenvector directions
    ls_ordered = [None, None]  # ordered eigenvalues
    vs_ordered = [None, None]  # ordered eigenvectors
    t0_diag = np.abs(np.dot(v0, v_diag))
    t0_codiag = np.abs(np.dot(v0, v_codiag))
    #print(f"t0_diag={t0_diag:.3f}, t0_codiag={t0_codiag:.3f}")
    t1_diag = np.abs(np.dot(v1, v_diag))
    t1_codiag = np.abs(np.dot(v1, v_codiag))
    #print(f"t1_diag={t1_diag:.3f}, t1_codiag={t1_codiag:.3f}")
    eps = 5e-2
    if np.allclose(t0_diag, 1, atol=eps):
        #print("v0 diagonal")
        vs_ordered[0] = v0
        ls_ordered[0] = l0
    if np.allclose(t0_codiag, 1, atol=eps):
        #print("v0 co-diagonal")
        vs_ordered[1] = v0
        ls_ordered[1] = l0
    if np.allclose(t1_diag, 1, atol=eps):
        #print("v1 diagonal")
        vs_ordered[0] = v1
        ls_ordered[0] = l1
    if np.allclose(t1_codiag, 1, atol=eps):
        #print("v1 co-diagonal")
        vs_ordered[1] = v1
        ls_ordered[1] = l1

    #print(f"eigenvalues: {l0:.2e} {l1:.2e}")
    #print(f"eigenvectors: ({v0[0]:.3f}, {v0[1]:.3f}), ({v1[0]:.3f}, {v1[1]:.3f})")

    l0, l1 = ls_ordered
    v0, v1 = vs_ordered[0], vs_ordered[1]
    #print(f"ordered eigenvalues: {l0:.2e} {l1:.2e}")
    #print(f"ordered eigenvectors: ({v0[0]:.3f}, {v0[1]:.3f}), ({v1[0]:.3f}, {v1[1]:.3f})")

    s0_hat = np.sqrt(l0)
    s1_hat = np.sqrt(l1)
    #print(f"\tsqrt of eigenvalues: {s0_hat:.3f}, {s1_hat:.3f}")

    if doplot:
        plt.figure(figsize=(6, 6))
        plt.plot(I[:-1], I[1:], 'ok', ms=6, alpha=0.5)
        plt.plot(I, I, '-k', lw=2)
        plt.plot(x_m, y_m, 'or', ms=8)
        plt.plot([x_m, x_m+s0_hat*v0[0]], [y_m, y_m+s0_hat*v0[1]], '-b', lw=5)
        plt.plot([x_m, x_m+s1_hat*v1[0]], [y_m, y_m+s1_hat*v1[1]], '-b', lw=5)
        #plt.xlim(I_min, I_max)
        #plt.ylim(I_min, I_max)
        plt.xlabel(r"$I_{n}$ [s]", fontsize=14)
        plt.ylabel(r"$I_{n+1}$ [s]", fontsize=14)
        plt.grid(True)
        plt.axis('equal')
        plt.tight_layout()
        plt.show()

    return s0_hat, s1_hat, v0, v1


def main():
    pass


if __name__ == "__main__":
    os.system("clear")
    main()

# %%
# Initial Inspect
L = os.listdir(data_dir)
for l in L:
    print(l)
# Out:
# ANNOTATORS
# infant10_ecg.atr
# infant10_ecg.dat
# infant10_ecg.hea
# infant10_ecg.qrsc
# infant10_resp.dat
# infant10_resp.hea
# infant10_resp.resp
# infant1_ecg.atr
# infant1_ecg.dat
# infant1_ecg.hea
# infant1_ecg.qrsc
# infant1_resp.dat
# infant1_resp.hea
# infant1_resp.resp
# infant2_ecg.atr
# infant2_ecg.dat
# infant2_ecg.hea
# infant2_ecg.qrsc
# infant2_resp.dat
# infant2_resp.hea
# infant2_resp.resp
# infant3_ecg.atr
# infant3_ecg.dat
# infant3_ecg.hea
# infant3_ecg.qrsc
# infant3_resp.dat
# infant3_resp.hea
# infant3_resp.resp
# infant4_ecg.atr
# infant4_ecg.dat
# infant4_ecg.hea
# infant4_ecg.qrsc
# infant4_resp.dat
# infant4_resp.hea
# infant4_resp.resp
# infant5_ecg.atr
# infant5_ecg.dat
# infant5_ecg.hea
# infant5_ecg.qrsc
# infant5_resp.dat
# infant5_resp.hea
# infant5_resp.resp
# infant6_ecg.atr
# infant6_ecg.dat
# infant6_ecg.hea
# infant6_ecg.qrsc
# infant6_resp.dat
# infant6_resp.hea
# infant6_resp.resp
# infant7_ecg.atr
# infant7_ecg.dat
# infant7_ecg.hea
# infant7_ecg.qrsc
# infant7_resp.dat
# infant7_resp.hea
# infant7_resp.resp
# infant8_ecg.atr
# infant8_ecg.dat
# infant8_ecg.hea
# infant8_ecg.qrsc
# infant8_resp.dat
# infant8_resp.hea
# infant8_resp.resp
# infant9_ecg.atr
# infant9_ecg.dat
# infant9_ecg.hea
# infant9_ecg.qrsc
# infant9_resp.dat
# infant9_resp.hea
# infant9_resp.resp
# RECORDS
# SHA256SUMS.txt

# %%
# Manual file selection
file_index = 3
file_ecg = os.path.join(data_dir, f"infant{file_index:d}_ecg")
file_resp = os.path.join(data_dir, f"infant{file_index:d}_resp")
print("Loading ECG file : ", file_ecg)
print("Loading RESP file: ", file_resp)
record_ecg = wfdb.rdrecord(file_ecg)
record_resp = wfdb.rdrecord(file_resp)
# Out:
# Loading ECG file :  E:\jupter-repos\picsdb\1.0.0\infant3_ecg
# Loading RESP file:  E:\jupter-repos\picsdb\1.0.0\infant3_resp

# %%
d_ecg = record_ecg.__dict__
d_resp = record_resp.__dict__
print(d_ecg)
# Out:
# {'record_name': 'infant3_ecg', 'n_sig': 1, 'fs': 500, 'counter_freq': None, 'base_counter': None, 'sig_len': 78684614, 'base_time': None, 'base_date': None, 'comments': [], 'sig_name': ['II'], 'p_signal': array([[ 0.09467079],
#        [ 0.09993028],
#        [ 0.09467079],
#        ...,
#        [-0.83976496],
#        [-0.91427437],
#        [-0.94407814]]), 'd_signal': None, 'e_p_signal': None, 'e_d_signal': None, 'file_name': ['infant3_ecg.dat'], 'fmt': ['16'], 'samps_per_frame': [1], 'skew': [None], 'byte_offset': [None], 'adc_gain': [1140.7954], 'baseline': [11394], 'units': ['mV'], 'adc_res': [0], 'adc_zero': [0], 'init_value': [11502], 'checksum': [22904], 'block_size': [0]}

# %%
print("ECG record: ", d_ecg['record_name'])
print("number of signals: ", d_ecg['n_sig'])
print("sampling frequency: ", d_ecg['fs'], "Hz")
print("Number of samples: ", d_ecg['sig_len'])
print("Signal name: ", d_ecg['sig_name'])
# Out:
# ECG record:  infant3_ecg
# number of signals:  1
# sampling frequency:  500 Hz
# Number of samples:  78684614
# Signal name:  ['II']

# %%
print("RESP record: ", d_resp['record_name'])
print("number of signals: ", d_resp['n_sig'])
print("sampling frequency: ", d_resp['fs'], "Hz")
print("Number of samples: ", d_resp['sig_len'])
print("Signal name: ", d_resp['sig_name'])
# Out:
# RESP record:  infant3_resp
# number of signals:  1
# sampling frequency:  50 Hz
# Number of samples:  7868296
# Signal name:  ['RESP']

# %%
# Next, extract the ECG/RESP data arrays and convert them into 1-dimensional arrays using ravel:
x_ecg = d_ecg['p_signal'].ravel()
print("Number of ECG samples: ", x_ecg.shape[0], " data type: ", x_ecg.dtype)
# Out:
# Number of ECG samples:  78684614  data type:  float64

# %%
x_resp = d_resp['p_signal'].ravel()
print("Number of RESP samples: ", x_resp.shape[0], " data type: ", x_resp.dtype)
# Out:
# Number of RESP samples:  7868296  data type:  float64

# %%
# interval = 1/frequency
fs_ecg = d_ecg['fs'] # ECG sampling rate in Hz
dt_ecg = 1/fs_ecg # ECG sampling interval in sec.
fs_resp = d_resp['fs'] # RESP sampling rate in Hz
dt_resp = 1/fs_resp # RESP sampling interval in sec.
print("ECG sampling frequency: ", fs_ecg, " Hz")
print("ECG sampling interval dt = ", dt_ecg, " sec.")
print("RESP sampling frequency: ", fs_resp, " Hz")
print("RESP sampling interval dt = ", dt_resp, " sec.")
# Out:
# ECG sampling frequency:  500  Hz
# ECG sampling interval dt =  0.002  sec.
# RESP sampling frequency:  50  Hz
# RESP sampling interval dt =  0.02  sec.

# %%
# Select time window manually
# set display time limits manually, recordings are many hours, millions of data points...
#t0_sec, t1_sec = 90620, 90640 # seconds

# ...or, if you want to look at the whole recording:
t0_sec, t1_sec = 0, x_resp.shape[0]*dt_resp # seconds, based on RESP signal

# convert seconds to samples, respect different sampling rates for ECG and RESP signals
t0_sample_ecg = round(t0_sec * fs_ecg)
t1_sample_ecg = round(t1_sec * fs_ecg)
t0_sample_resp = round(t0_sec * fs_resp)
t1_sample_resp = round(t1_sec * fs_resp)

# %%
# plot 
# this tells the notebook to open figures outside of the notebook
#%matplotlib qt
# %matplotlib inline

time_ecg = np.arange(x_ecg.shape[0])*dt_ecg # ECG time axis
time_resp = np.arange(x_resp.shape[0])*dt_resp # RESP time axis

fig1, ax = plt.subplots(2, 1, figsize=(16,4), sharex=True)
ax[0].plot(time_ecg[t0_sample_ecg:t1_sample_ecg], x_ecg[t0_sample_ecg:t1_sample_ecg], '-k', lw=0.5)
ax[1].plot(time_resp[t0_sample_resp:t1_sample_resp], x_resp[t0_sample_resp:t1_sample_resp], '-k', lw=0.5)
ax[0].set_xlabel("time [sec]")
ax[1].set_xlabel("time [sec]")
ax[0].set_title("ECG")
ax[1].set_title("RESP")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PART2 Selection of sample segments
# Use the manually selected segment borders (in seconds) that were identified
# **Can add a random function here**
# List item
# List item
# visually using picsdb1_inspect.ipynb:

# %%
# A
segments = {}
for i in range(10):
    key = f"infant{i+1:d}"
    segments[key] = []
segments['infant1'] = [(3550, 3750), (4720,4822), (5100,5280), (7760,7870), (11435,11550)]
segments['infant1'] = [(3550,7870)]
segments['infant2'] = [(3990,12080)]
#segments['infant1'] = [(5110,5355)]
#segments['infant2'] = [(3955,3960)]
segments['infant3'] = [(5575,13940)]
segments['infant4'] = [(5860,12980)]
segments['infant5'] = [(103750,147350)] #FINAL
segments['infant6'] = [(7130,13670)]
segments['infant7'] = [(5060,13630)]
segments['infant8'] = [(4880,14570)]
segments['infant9'] = [(5940,12580)]
segments['infant10'] = [(3225,14710)]

# %% [markdown]
# ## PART3 Select thresholds for peak detection for each sample
# Part 3 will be re-ran every segement. The final thresholds selected will be recorded in columns D to K of 'Preterm Infant Data Input Settings Blank' excel spreadsheet.
#
# Our complete and filled out excel spreadsheet is titled 'Preterm Infant Data Input Settings'. Refer to that if wanting to produce our exact results.
#
# ### Step One: Select segement to work with
#
# Select a segment to work with by entering in an Infant number/ file_index (1 to 10) and a segement number
#
# file_index = 2 # 1...10, loads data from infant1 ... infant10 segment_index = 0

# %%
file_index = 2 # 1...10, loads data from infant1 ... infant10
segment_index = 0 # 0,...

# %% [markdown]
# ## Step two: Import all the revelent data for that segement
# Similar to part 1, the data will be imported but only part of the signal. Part 2, Step Two created a dictionary that will be used so the correct segment of time is selected from the overall signal and Part 3, Step One determines which segment it is.

# %%
# Data Import
x_ecg_full, x_resp_full, fs_ecg, fs_resp = load_waveforms(data_dir, file_index)
dt_ecg = 1/fs_ecg # ECG sampling interval in sec.
dt_resp = 1/fs_resp # RESP sampling interval in sec.
print("ECG sampling interval dt = ", dt_ecg, " sec.")
print("RESP sampling interval dt = ", dt_resp, " sec.")
# Out:
# Loading ECG file:  infant2_ecg
# Loading RESP file:  infant2_resp
# ECG sampling frequency:  500  Hz
# RESP sampling frequency:  50  Hz
# ECG sampling interval dt =  0.002  sec.
# RESP sampling interval dt =  0.02  sec.

# %% [markdown]
# *Clip* data to segment borders:

# %%
# get segment borders in seconds from the 'segments' dictionary
t0_sec, t1_sec = segments[f"infant{file_index:d}"][segment_index]
# convert seconds to samples, respect different sampling rates for ECG and RESP signals
t0_sample_ecg = round(t0_sec * fs_ecg)
t1_sample_ecg = round(t1_sec * fs_ecg)
t0_sample_resp = round(t0_sec * fs_resp)
t1_sample_resp = round(t1_sec * fs_resp)

# %%
print(t0_sample_ecg)
print(t1_sample_ecg)
print(t0_sample_resp)
print(t1_sample_resp)
# Out:
# 1995000
# 6040000
# 199500
# 604000

# %%
# Extract the ECG and RESP data arrays and convert them to a 1-dimensional arrays:
x_ecg = x_ecg_full[t0_sample_ecg:t1_sample_ecg] #sample for ecg
x_resp = x_resp_full[t0_sample_resp:t1_sample_resp]
print("number of ECG samples: ", len(x_ecg) , " data type: ", x_ecg.dtype)
print("number of RESP samples: ", x_resp.shape[0], " data type: ", x_resp.dtype)
# Out:
# number of ECG samples:  4045000  data type:  float64
# number of RESP samples:  404500  data type:  float64

# %%
del x_ecg_full, x_resp_full # free memory

# %% [markdown]
# Invert ECG signal if necessary.
#
# mn = np.min(x_ecg-np.median(x_ecg)) mx = np.max(x_ecg-np.median(x_ecg)) if np.abs(mn) > np.abs(mx): print("Invert ECG signal!") x_ecg = -x_ecg
#
# ### Step Three: Plot the signal to check the segment selected

# %%
# open figures outside of the notebook
#%matplotlib qt
# %matplotlib inline

# ECG/RESP time axes [sec]
time_ecg = np.arange(x_ecg.shape[0])*dt_ecg
time_resp = np.arange(x_resp.shape[0])*dt_resp

# %% [markdown]
# Step Four: Define a few functions to process the signal with
#
# A) Bandwidth filter (filters out extreme frequency signals that are out of what's is physically possible)
# B) Local Maxima- to detect the peak of a wave
# C) Histogram- to look at distribution
# D) Interval Statistics
# NOTE: These functions have been moved from the notebook into the external file picsdb.py

# %% [markdown]
# # ECG/RESP peak detection algorithm
#
# *   **List item**
# *   List item

# %%
x=x_ecg
iSampleCount=x.shape[0]
iSampleRate=fs_ecg
t = np.linspace(0,iSampleCount/iSampleRate,iSampleCount)
 
xFFT = np.abs(np.fft.rfft(x)/iSampleCount)  #快速傅里叶变换
#xFreqs = np.linspace(0, iSampleRate/2, int(iSampleCount/2)+1)
xFreqs = np.linspace(0, iSampleRate/2, int(iSampleCount/2)+1)
plt.figure(figsize=(25,10))
ax0 = plt.subplot(211)             #画时域信号
ax0.set_xlabel("Time(s)")
ax0.set_ylabel("Amp(mV)")
ax0.plot(t,x)
 
ax1 = plt.subplot(212)             #画频域信号-频谱
ax1.set_xlabel("Freq(Hz)")
ax1.set_ylabel("Power")

ax1.plot(xFreqs, xFFT)

# %% [markdown]
# # Plot power spectra
#
# First, inspect the power spectral densities of ECG/RESP signals to get an idea of useful settings for the band-pass filters.
#
# **Step Five: Define cut-off frequencies for ECG and RESP signals**
#
# These cut-off frequencies are chosen based off a combination of what is physiologically possible and the sampling frequency of the signal. They should be kept the same across all infants HOWEVER infant 1 and 5's ECG sampling rate was 250Hz instead of 500Hz. Therefore, we had to lower the freq_hi_ecg setting to 120Hz, as the value must be less than half the sampling rate. The rest of the infants freq_hi_ecg was 125Hz.
#
# The following cell allows you to check if your settings work for the sample. Record the settings in column D, E, F and G in 'Preterm Infant Data Input Settings Blank'.

# %%
freq_lo_ecg = 20
freq_hi_ecg = 125 # if is 1 or 5, use 120
freq_lo_resp = 0.5
freq_hi_resp = 5 # 5

# %% [markdown]
# **Step Six: Apply the band-pass filter**
#
# Using the function defined in step 4, A and the settings defined in step 5, a band-pass filter is created and applied to further filter out any signals that could be aretfacts/ background.

# %%
x_ecg_filt  = bp_filter(x_ecg, fs_ecg, freq_lo_ecg, freq_hi_ecg)
x_resp_filt = bp_filter(x_resp, fs_resp, freq_lo_resp, freq_hi_resp)

# %%
x_resp_filt_re=processing.resample_sig(x_resp_filt,fs=50,fs_target=500)[0]
from scipy import signal

# %%
testresp=x_resp_filt
plt.figure(figsize=(16,5))
time=np.arange(2*len(testresp),step=2)
plt.scatter(time, testresp, color = 'hotpink',s=1,label='Before Resampling')
#plt.scatter(time_resp, x_resp, color = '#88c999')
i=np.array(testresp)
res=processing.resample_sig(i,fs=500,fs_target=1000)
plt.ylabel("Signal")
time=np.arange(2*len(testresp))
plt.scatter(time, res[0], color = 'green',s=1,alpha=0.5,label='After Resampling')
plt.legend(labels=["Before Resampling","After Resampling"],loc="upper left",fontsize=6)  
plt.title("Resample function")
plt.show()

# %% [markdown]
# Resample the ecg sig
#
# base on ecg and resp freq

# %%
x_resp_filt=processing.resample_sig(x_resp_filt,fs=50,fs_target=500)[0]
x_ecg=x_ecg_filt
print(len(x_resp_filt))
print(len(x_ecg))
# Out:
# 4045000
# 4045000

# %% [markdown]
# get the single resp wave

# %%
x_resp_flow=[]
floewer=[]

x_ecg_flow=[]
ecg_flow=[]


time_resp_temp=time_ecg
time_ecg_temp=time_resp

x_temp=[]
temp=[]
for i in range(0,len(x_resp_filt)-1,1):
    if i==0:
        floewer.append(x_resp_filt[i])
        ecg_flow.append(x_ecg[i])
        temp.append(time_resp_temp[i])
        #ecg.append(time_ecg_temp[i])
    else:
        floewer.append(x_resp_filt[i])
        temp.append(time_resp_temp[i])
        ecg_flow.append(x_ecg[i])
        #ecg.append(time_resp_temp[i])
        if not (x_resp_filt[i]<x_resp_filt[i+1] and x_resp_filt[i]<=x_resp_filt[i-1]):
            pass
        else:
            x_resp_flow.append(floewer)
            x_ecg_flow.append(ecg_flow)
            x_temp.append(temp)
            #ecg_temp.append(ecg)
            floewer=[]
            ecg_flow=[]
            temp=[]
            #ecg=[]
lens=len(x_temp)
fig2, ax = plt.subplots(5, 1, figsize=(5,3), sharex=True)
#x_resp_flow.remove(x_resp_flow[0])
#x_temp.remove(x_temp[0])
#x_ecg_flow.remove(x_ecg_flow[0])
j=0
for i in range(0,5):
    ax[j].plot(x_temp[i], x_resp_flow[i], '-k', lw=1)
    ax[j].set_xlabel("time [sec]")
    ax[j].set_title("RESP")
    j+=1

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Flynn\AppData\Local\Temp\ipykernel_43580\3392795584.py:47: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig2, ax = plt.subplots(5, 1, figsize=(16,13), sharex=True)
j=0
for i in range(0,5):
    ax[j].plot(x_temp[i], x_ecg_flow[i], '-k', lw=1)
    ax[j].set_xlabel("time [sec]")
    ax[j].set_title("ECG")
    j+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# conbain the uncontinue data
#
# remove some data
#
# I still working on finding someway to fix the discontinuous data, so I drop them.
#
# If we can combain the discontinuous data, this function can be delete

# %%
for i in x_resp_flow:
    if(len(i)<200):
        x_resp_flow.remove(i)

for j in x_ecg_flow:
    if(len(j)<200):
        x_ecg_flow.remove(j)

for z in x_temp:
    if(len(z)<200):
        x_temp.remove(z)

# %%
# find the R wave for each part ecg wave
lomx=[]
w=1
for z in x_ecg_flow:
    c=locmax(z)
    ecg_peaks = np.array([np.mean(z[i-w:i+w]) for i in c])
    c = np.array([j for i, j in enumerate(c) if ecg_peaks[i] > 0.12]) #ecg_peacks > 0.12 / 0.2
    lomx.append(c)
print(len(lomx))
# Out:
# 10158

# %%
lomx
# Out:
# [array([], dtype=float64),
#  array([], dtype=float64),
#  array([132, 148, 385, 401], dtype=int64),
#  array([132, 148, 391, 406], dtype=int64),
#  array([ 69,  84, 325, 341], dtype=int64),
#  array([  9,  25, 270, 286], dtype=int64),
#  array([ 20,  36, 281, 296], dtype=int64),
#  array([146, 162, 398, 414], dtype=int64),
#  array([173, 188, 421, 437], dtype=int64),
#  array([142, 158], dtype=int64),
#  array([  3,  19, 260, 276], dtype=int64),
#  array([ 20,  35, 282, 298], dtype=int64),
#  array([146, 162], dtype=int64),
#  array([ 26,  41, 276, 291], dtype=int64),
#  array([ 19,  35, 269, 284], dtype=int64),
#  array([112, 128, 355, 371], dtype=int64),
#  array([135, 151, 378, 394], dtype=int64),
#  array([226, 242], dtype=int64),
#  array([127, 143], dtype=int64),
#  array([ 21,  37, 272, 287], dtype=int64),
#  array([114, 130, 369, 385], dtype=int64),
#  array([232, 248], dtype=int64),
#  array([ 37,  52, 294, 310], dtype=int64),
#  array([124, 140, 380, 396], dtype=int64),
#  array([208, 223], dtype=int64),
#  array([ 53,  69, 302, 317], dtype=int64),
#  array([174, 190, 417, 433], dtype=int64),
#  array([205, 221], dtype=int64),
#  array([ 37,  53, 279, 295], dtype=int64),
#  array([145, 161], dtype=int64),
#  array([ 72,  88, 324, 340], dtype=int64),
#  array([216, 232], dtype=int64),
#  array([148, 164], dtype=int64),
#  array([ 88, 104], dtype=int64),
#  array([  8,  24, 270, 286], dtype=int64),
#  array([195, 211], dtype=int64),
#  array([146, 162], dtype=int64),
#  array([ 71,  87, 330, 346], dtype=int64),
#  array([228, 244], dtype=int64),
#  array([151, 166, 400, 415], dtype=int64),
#  array([214, 230, 461], dtype=int64),
#  array([  5, 241, 256], dtype=int64),
#  array([109, 124, 364], dtype=int64),
#  array([  7, 248, 264], dtype=int64),
#  array([112, 128, 370], dtype=int64),
#  array([ 10, 251, 267], dtype=int64),
#  array([ 61,  76, 314, 330], dtype=int64),
#  array([ 67,  83, 317, 333], dtype=int64),
#  array([ 62,  78, 312, 328], dtype=int64),
#  array([121, 137, 373, 388], dtype=int64),
#  array([173, 189], dtype=int64),
#  array([  4,  19, 259, 275], dtype=int64),
#  array([ 40,  56, 297, 313], dtype=int64),
#  array([164, 179], dtype=int64),
#  array([ 80,  96, 331, 347], dtype=int64),
#  array([202, 218], dtype=int64),
#  array([ 19,  34, 269, 285], dtype=int64),
#  array([110, 126, 357, 372], dtype=int64),
#  array([208, 224], dtype=int64),
#  array([ 20,  35, 267, 283], dtype=int64),
#  array([ 24,  40, 267, 283], dtype=int64),
#  array([ 15,  31, 254, 270, 493], dtype=int64),
#  array([  3, 229, 245], dtype=int64),
#  array([147, 163], dtype=int64),
#  array([ 74,  90, 324, 339], dtype=int64),
#  array([179, 194], dtype=int64),
#  array([124, 140], dtype=int64),
#  array([ 62,  77, 315, 331], dtype=int64),
#  array([229, 244], dtype=int64),
#  array([168, 184], dtype=int64),
#  array([ 53,  69, 305, 320], dtype=int64),
#  array([156, 171], dtype=int64),
#  array([ 40,  56, 291, 307], dtype=int64),
#  array([221, 237], dtype=int64),
#  array([170, 186], dtype=int64),
#  array([153, 169], dtype=int64),
#  array([114, 129], dtype=int64),
#  array([ 86, 101], dtype=int64),
#  array([ 84, 100], dtype=int64),
#  array([ 51,  67, 286, 302], dtype=int64),
#  array([214, 229], dtype=int64),
#  array([107, 123], dtype=int64),
#  array([38, 54], dtype=int64),
#  array([ 14,  30, 258, 274], dtype=int64),
#  array([200, 216], dtype=int64),
#  array([156, 172], dtype=int64),
#  array([130, 146], dtype=int64),
#  array([  3,  19, 243, 259], dtype=int64),
#  array([ 88, 104, 327, 343], dtype=int64),
#  array([ 93, 109, 331, 347], dtype=int64),
#  array([145, 161, 380, 396], dtype=int64),
#  array([178, 194, 413], dtype=int64),
#  array([  5, 231, 247], dtype=int64),
#  array([ 16,  32, 265, 281, 520, 536], dtype=int64),
#  array([216, 232, 474, 489], dtype=int64),
#  array([  4, 245, 261, 506, 521], dtype=int64),
#  array([184, 200, 436, 451], dtype=int64),
#  array([157, 173, 409, 424], dtype=int64),
#  array([159, 175, 411, 427], dtype=int64),
#  array([ 98, 114, 348, 364], dtype=int64),
#  array([ 36,  52, 281, 296], dtype=int64),
#  array([218, 234], dtype=int64),
#  array([ 10,  26, 258, 274, 504, 520], dtype=int64),
#  array([ 65,  81, 308, 324], dtype=int64),
#  array([15, 50], dtype=int64),
#  array([155, 393], dtype=int64),
#  array([101, 117, 337, 353], dtype=int64),
#  array([219, 235, 450, 466], dtype=int64),
#  array([207, 222, 435, 450], dtype=int64),
#  array([175, 191, 402, 418], dtype=int64),
#  array([107, 123, 345, 361], dtype=int64),
#  array([123, 139, 367, 383], dtype=int64),
#  array([125, 141], dtype=int64),
#  array([120, 136, 364, 380], dtype=int64),
#  array([ 98, 114], dtype=int64),
#  array([121, 137, 373, 389], dtype=int64),
#  array([168, 184, 413, 429], dtype=int64),
#  array([174, 190, 416, 432], dtype=int64),
#  array([142, 158, 390, 406], dtype=int64),
#  array([120, 136, 372, 388], dtype=int64),
#  array([ 30,  46, 285, 301, 536, 552], dtype=int64),
#  array([ 21,  37, 274, 290, 526, 542], dtype=int64),
#  array([63, 79], dtype=int64),
#  array([209, 225, 465, 481], dtype=int64),
#  array([157, 173, 418, 434, 675], dtype=int64),
#  array([ 13, 256, 272, 514, 530], dtype=int64),
#  array([212, 228], dtype=int64),
#  array([45, 61], dtype=int64),
#  array([], dtype=float64),
#  array([162], dtype=int64),
#  array([], dtype=float64),
#  array([178, 193], dtype=int64),
#  array([127, 143], dtype=int64),
#  array([166, 182], dtype=int64),
#  array([128, 144], dtype=int64),
#  array([ 38,  54, 284, 300], dtype=int64),
#  array([193, 209], dtype=int64),
#  array([], dtype=float64),
#  array([158, 174], dtype=int64),
#  array([176, 191], dtype=int64),
#  array([60, 76], dtype=int64),
#  array([ 99, 115, 348, 364], dtype=int64),
#  array([210, 226], dtype=int64),
#  array([126, 142], dtype=int64),
#  array([194, 209], dtype=int64),
#  array([120, 136], dtype=int64),
#  array([ 91, 107, 343, 359], dtype=int64),
#  array([132, 148], dtype=int64),
#  array([112, 128, 353, 369], dtype=int64),
#  array([ 67, 309], dtype=int64),
#  array([217, 233], dtype=int64),
#  array([213, 229, 450, 466], dtype=int64),
#  array([105, 120, 340, 356, 577, 593], dtype=int64),
#  array([80, 95], dtype=int64),
#  array([ 78,  94, 322, 337], dtype=int64),
#  array([ 30,  46, 277, 293], dtype=int64),
#  array([130, 146, 387, 403], dtype=int64),
#  array([ 98, 114, 368, 384], dtype=int64),
#  array([219, 235, 497, 513], dtype=int64),
#  array([18, 34], dtype=int64),
#  array([], dtype=float64),
#  array([ 8, 24], dtype=int64),
#  array([ 88, 105, 352, 368], dtype=int64),
#  array([210, 226, 472, 488, 737, 753], dtype=int64),
#  array([ 96, 112, 359, 375], dtype=int64),
#  array([166, 182], dtype=int64),
#  array([155, 171], dtype=int64),
#  array([ 97, 113, 363, 379], dtype=int64),
#  array([166, 182, 430, 446], dtype=int64),
#  array([ 99, 115, 362, 378], dtype=int64),
#  array([167, 183], dtype=int64),
#  array([167, 183, 430, 446], dtype=int64),
#  array([185, 201], dtype=int64),
#  array([ 11,  27, 273, 289], dtype=int64),
#  array([151, 167], dtype=int64),
#  array([134, 150], dtype=int64),
#  array([184, 200], dtype=int64),
#  array([153, 169], dtype=int64),
#  array([ 65,  81, 319, 335], dtype=int64),
#  array([157, 173, 408, 424], dtype=int64),
#  array([162, 179, 410, 426], dtype=int64),
#  array([133, 149, 383, 399], dtype=int64),
#  array([ 23,  39, 278, 294, 529, 545], dtype=int64),
#  array([159, 175, 417, 433], dtype=int64),
#  array([ 54,  70, 322, 339], dtype=int64),
#  array([ 42,  58, 304, 320, 560, 575], dtype=int64),
#  array([130, 146, 388, 404, 641, 657], dtype=int64),
#  array([ 48,  64, 312, 328, 572, 588], dtype=int64),
#  array([161, 177, 427, 443], dtype=int64),
#  array([146, 162, 421, 437], dtype=int64),
#  array([158, 174, 436, 452], dtype=int64),
#  array([177, 193, 456, 472], dtype=int64),
#  array([230, 245], dtype=int64),
#  array([ 49,  65, 326, 342], dtype=int64),
#  array([ 87, 103, 367, 382], dtype=int64),
#  array([228, 244], dtype=int64),
#  array([136, 152], dtype=int64),
#  array([ 70,  86, 342, 358], dtype=int64),
#  array([150, 166], dtype=int64),
#  array([116, 132], dtype=int64),
#  array([136, 152], dtype=int64),
#  array([82, 98], dtype=int64),
#  array([185], dtype=int64),
#  array([224, 239], dtype=int64),
#  array([101, 117, 335, 351, 568, 584], dtype=int64),
#  array([146, 162, 377, 393, 607, 623], dtype=int64),
#  array([209, 225, 447, 463], dtype=int64),
#  array([212, 228, 457, 473], dtype=int64),
#  array([216, 232, 462, 478], dtype=int64),
#  array([193, 209, 439, 456], dtype=int64),
#  array([216, 232, 462, 478], dtype=int64),
#  array([191, 207], dtype=int64),
#  array([  3,  19, 264, 280], dtype=int64),
#  array([ 41,  57, 307, 323], dtype=int64),
#  array([ 59,  75, 327, 343], dtype=int64),
#  array([ 94, 110, 362, 378, 622, 638], dtype=int64),
#  array([225, 241, 485, 501], dtype=int64),
#  array([171, 187, 437, 453], dtype=int64),
#  array([205, 221], dtype=int64),
#  array([ 15,  31, 285, 301], dtype=int64),
#  array([161, 177], dtype=int64),
#  array([ 69,  85, 336, 352], dtype=int64),
#  array([148, 165, 417, 433], dtype=int64),
#  array([193, 209, 470, 486], dtype=int64),
#  array([123, 139], dtype=int64),
#  array([109, 125], dtype=int64),
#  array([106, 122], dtype=int64),
#  array([185, 201], dtype=int64),
#  array([ 53,  69, 321], dtype=int64),
#  array([  3, 258, 274], dtype=int64),
#  array([172, 188], dtype=int64),
#  array([173, 189], dtype=int64),
#  array([215, 231], dtype=int64),
#  array([195, 211], dtype=int64),
#  array([188, 205], dtype=int64),
#  array([189, 205], dtype=int64),
#  array([70, 86], dtype=int64),
#  array([142, 157], dtype=int64),
#  array([ 14,  30, 281, 297], dtype=int64),
#  array([ 40,  56, 303, 319], dtype=int64),
#  array([ 22,  38, 280, 296], dtype=int64),
#  array([126, 142], dtype=int64),
#  array([ 11,  27, 273, 289], dtype=int64),
#  array([177, 193], dtype=int64),
#  array([ 41,  57, 310], dtype=int64),
#  array([  8, 262, 278], dtype=int64),
#  array([202, 218], dtype=int64),
#  array([149, 165], dtype=int64),
#  array([77, 93], dtype=int64),
#  array([  1,  17, 260, 276], dtype=int64),
#  array([206, 222], dtype=int64),
#  array([153, 168], dtype=int64),
#  array([74, 90], dtype=int64),
#  array([  2,  17, 272, 288], dtype=int64),
#  array([215], dtype=int64),
#  array([  5, 253, 269], dtype=int64),
#  array([208, 224], dtype=int64),
#  array([207, 223], dtype=int64),
#  array([221, 237], dtype=int64),
#  array([205, 221], dtype=int64),
#  array([121, 137, 383, 399], dtype=int64),
#  array([119, 135], dtype=int64),
#  array([26, 42], dtype=int64),
#  array([  6,  22, 305, 321], dtype=int64),
#  array([241], dtype=int64),
#  array([  5, 257, 272], dtype=int64),
#  array([221, 237], dtype=int64),
#  array([204, 220], dtype=int64),
#  array([239, 255], dtype=int64),
#  array([205, 221], dtype=int64),
#  array([148, 163], dtype=int64),
#  array([ 17,  33, 311, 327], dtype=int64),
#  array([164, 180, 430, 445], dtype=int64),
#  array([224, 240, 475, 491], dtype=int64),
#  array([126, 142, 368, 384, 438], dtype=int64),
#  array([ 10, 237], dtype=int64),
#  array([ 69,  85, 308, 323, 545], dtype=int64),
#  array([109, 126, 343, 359], dtype=int64),
#  array([  1,  17, 234, 250], dtype=int64),
#  array([ 84, 100, 313, 329, 541, 557], dtype=int64),
#  array([156, 172, 384, 400], dtype=int64),
#  array([136, 152, 363, 379], dtype=int64),
#  array([ 36,  52, 270, 285], dtype=int64),
#  array([  9,  24, 244, 260], dtype=int64),
#  array([ 17,  33, 252, 268, 489, 504], dtype=int64),
#  array([203, 219, 441, 456], dtype=int64),
#  array([  1,  17, 255, 271, 506, 522], dtype=int64),
#  array([181, 197], dtype=int64),
#  array([ 50,  66, 309, 325], dtype=int64),
#  array([186, 202], dtype=int64),
#  array([ 27,  43, 289, 305], dtype=int64),
#  array([178, 194, 440, 456, 493], dtype=int64),
#  array([ 17, 201, 217], dtype=int64),
#  array([ 34,  50, 281, 297], dtype=int64),
#  array([ 44,  59, 290, 306, 535], dtype=int64),
#  array([122, 138], dtype=int64),
#  array([107, 123, 344, 360], dtype=int64),
#  array([40, 56], dtype=int64),
#  array([171, 187, 416, 432], dtype=int64),
#  array([135, 151], dtype=int64),
#  array([124, 141, 371, 387], dtype=int64),
#  array([155, 171], dtype=int64),
#  array([ 93, 109, 357, 373], dtype=int64),
#  array([235, 251, 493, 508], dtype=int64),
#  array([176, 192], dtype=int64),
#  array([ 32,  48, 287, 303], dtype=int64),
#  array([141, 157], dtype=int64),
#  array([ 45,  61, 295, 311], dtype=int64),
#  array([141, 157], dtype=int64),
#  array([102, 118], dtype=int64),
#  array([45, 61], dtype=int64),
#  array([ 1, 17], dtype=int64),
#  array([ 7, 23], dtype=int64),
#  array([16], dtype=int64),
#  array([ 8, 24], dtype=int64),
#  array([75, 91], dtype=int64),
#  array([81, 97], dtype=int64),
#  array([ 33,  50, 293, 308], dtype=int64),
#  array([159, 176], dtype=int64),
#  array([56, 72], dtype=int64),
#  array([  5,  21, 270, 287], dtype=int64),
#  array([207, 223], dtype=int64),
#  array([ 67,  83, 332, 348], dtype=int64),
#  array([117, 133, 387, 403], dtype=int64),
#  array([147, 163, 409, 425], dtype=int64),
#  array([], dtype=float64),
#  array([ 24,  40, 287, 303], dtype=int64),
#  array([122, 139, 388, 404], dtype=int64),
#  array([181, 197, 473], dtype=int64),
#  array([  4, 265, 281], dtype=int64),
#  array([ 37,  53, 306, 322], dtype=int64),
#  array([ 69,  85, 343, 359], dtype=int64),
#  array([171, 187], dtype=int64),
#  array([ 19,  35, 281, 297], dtype=int64),
#  array([ 77,  93, 340, 356], dtype=int64),
#  array([198, 214], dtype=int64),
#  array([ 46,  62, 306, 322], dtype=int64),
#  array([192, 208], dtype=int64),
#  array([154, 170], dtype=int64),
#  array([134, 150], dtype=int64),
#  array([ 95, 111], dtype=int64),
#  array([53, 69], dtype=int64),
#  array([ 23,  38, 297], dtype=int64),
#  array([ 11, 268], dtype=int64),
#  array([  8, 263, 279], dtype=int64),
#  array([257, 273], dtype=int64),
#  array([243, 258], dtype=int64),
#  array([207, 223], dtype=int64),
#  array([ 94, 110], dtype=int64),
#  array([ 13,  29, 274, 290], dtype=int64),
#  array([ 88, 103], dtype=int64),
#  array([205, 221, 454], dtype=int64),
#  array([ 35,  51, 276, 292], dtype=int64),
#  array([44, 59], dtype=int64),
#  array([], dtype=float64),
#  array([124, 140, 360, 376], dtype=int64),
#  array([196, 212, 430, 446], dtype=int64),
#  array([101, 117, 336, 352], dtype=int64),
#  array([ 39,  55, 273, 289], dtype=int64),
#  array([ 41,  57, 275, 292], dtype=int64),
#  array([50, 66], dtype=int64),
#  array([ 60,  76, 330, 345], dtype=int64),
#  array([238, 254], dtype=int64),
#  array([  4,  20, 278, 294], dtype=int64),
#  array([235, 252, 524, 540], dtype=int64),
#  array([162, 179, 457, 473], dtype=int64),
#  array([258, 273], dtype=int64),
#  array([114, 130, 396, 412], dtype=int64),
#  array([ 17,  32, 294, 310, 577, 593], dtype=int64),
#  array([194, 211], dtype=int64),
#  array([  2,  18, 280, 296], dtype=int64),
#  array([208, 224], dtype=int64),
#  array([227, 243], dtype=int64),
#  array([188, 204], dtype=int64),
#  array([181, 197], dtype=int64),
#  array([158, 174], dtype=int64),
#  array([ 99, 115, 377], dtype=int64),
#  array([  4, 271, 287], dtype=int64),
#  array([190, 206], dtype=int64),
#  array([106, 122], dtype=int64),
#  array([ 16, 275, 291], dtype=int64),
#  array([189, 205], dtype=int64),
#  array([145, 161], dtype=int64),
#  array([ 67,  83, 333, 349], dtype=int64),
#  array([212, 229], dtype=int64),
#  array([148, 164], dtype=int64),
#  array([ 39,  55, 302, 318], dtype=int64),
#  array([209, 225], dtype=int64),
#  array([184, 200], dtype=int64),
#  array([147, 163], dtype=int64),
#  array([ 96, 112], dtype=int64),
#  array([ 30,  46, 299], dtype=int64),
#  array([ 11, 266], dtype=int64),
#  array([  8, 261, 277], dtype=int64),
#  array([236, 252], dtype=int64),
#  array([244, 259], dtype=int64),
#  array([207, 223], dtype=int64),
#  array([105, 120], dtype=int64),
#  array([165, 180], dtype=int64),
#  array([ 22,  38, 296, 312], dtype=int64),
#  array([151, 167], dtype=int64),
#  array([ 17,  33, 267, 284], dtype=int64),
#  array([172, 188], dtype=int64),
#  array([151, 167], dtype=int64),
#  array([130, 146], dtype=int64),
#  array([ 67,  83, 308], dtype=int64),
#  array([  1, 227, 243], dtype=int64),
#  array([203, 219], dtype=int64),
#  array([212, 228], dtype=int64),
#  array([153, 170], dtype=int64),
#  array([ 51,  66, 301, 317], dtype=int64),
#  array([184, 200], dtype=int64),
#  array([ 54,  70, 314, 330], dtype=int64),
#  array([191, 207], dtype=int64),
#  array([246, 262], dtype=int64),
#  array([114, 130], dtype=int64),
#  array([ 44,  60, 298, 314], dtype=int64),
#  array([203, 219], dtype=int64),
#  array([191, 207], dtype=int64),
#  array([176, 192], dtype=int64),
#  array([220, 236], dtype=int64),
#  array([184, 200], dtype=int64),
#  array([ 42,  57, 297, 313], dtype=int64),
#  array([  3, 237, 253], dtype=int64),
#  array([ 17,  32, 260, 276], dtype=int64),
#  array([193, 209], dtype=int64),
#  array([192, 209, 432, 448], dtype=int64),
#  array([198, 214], dtype=int64),
#  array([175, 191, 418, 434], dtype=int64),
#  array([159, 175, 399, 415], dtype=int64),
#  array([133, 150, 369, 385], dtype=int64),
#  array([ 47,  63, 282, 298], dtype=int64),
#  array([ 14,  30, 245], dtype=int64),
#  array([81, 97], dtype=int64),
#  array([215, 230, 448, 464], dtype=int64),
#  array([ 81,  97, 313, 329], dtype=int64),
#  array([ 54,  70, 293, 309, 536], dtype=int64),
#  array([  3, 231, 246], dtype=int64),
#  array([184, 200, 440, 456], dtype=int64),
#  array([204, 220], dtype=int64),
#  array([ 64,  80, 337, 353], dtype=int64),
#  array([143, 159], dtype=int64),
#  array([125, 141, 379, 395], dtype=int64),
#  array([189, 205, 455], dtype=int64),
#  array([  1, 250, 266], dtype=int64),
#  array([ 56,  72, 315, 331], dtype=int64),
#  array([145, 161, 403, 419], dtype=int64),
#  array([166, 182], dtype=int64),
#  array([158, 174], dtype=int64),
#  array([  4,  19, 274, 290], dtype=int64),
#  array([  6,  22, 267, 283, 522, 538], dtype=int64),
#  array([177, 193, 434, 450], dtype=int64),
#  array([153, 170, 413, 429], dtype=int64),
#  array([ 38,  53, 300, 317, 560, 576], dtype=int64),
#  array([233, 249], dtype=int64),
#  array([ 35,  51, 302, 318], dtype=int64),
#  array([123, 139], dtype=int64),
#  array([52, 68], dtype=int64),
#  array([165, 181], dtype=int64),
#  array([11, 27], dtype=int64),
#  array([23, 39], dtype=int64),
#  array([ 5, 21], dtype=int64),
#  array([162, 178], dtype=int64),
#  array([131, 147], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([165, 181, 434, 450], dtype=int64),
#  array([ 89, 105, 366, 382], dtype=int64),
#  array([153, 169], dtype=int64),
#  array([  1,  17, 270, 286], dtype=int64),
#  array([124, 141], dtype=int64),
#  array([ 29,  45, 282, 298], dtype=int64),
#  array([185, 201], dtype=int64),
#  array([130, 146], dtype=int64),
#  array([ 57,  73, 312], dtype=int64),
#  array([  3, 241, 258], dtype=int64),
#  array([169, 185], dtype=int64),
#  array([149, 166, 400, 416], dtype=int64),
#  array([ 73,  89, 324, 340], dtype=int64),
#  array([157, 173, 408, 424], dtype=int64),
#  array([150, 166, 411, 427], dtype=int64),
#  array([156, 172, 420, 435], dtype=int64),
#  array([197, 213], dtype=int64),
#  array([  9,  25, 276, 292], dtype=int64),
#  array([100, 116], dtype=int64),
#  array([], dtype=float64),
#  array([ 59,  75, 325, 341], dtype=int64),
#  array([], dtype=float64),
#  array([129, 145, 399, 415], dtype=int64),
#  array([201, 217, 470, 486], dtype=int64),
#  array([232, 247], dtype=int64),
#  array([ 89, 105, 336, 352, 581, 597], dtype=int64),
#  array([145, 161, 392, 408], dtype=int64),
#  array([164, 180], dtype=int64),
#  array([ 44,  60, 289, 305], dtype=int64),
#  array([220, 236], dtype=int64),
#  array([ 63,  79, 317, 332], dtype=int64),
#  array([209, 225], dtype=int64),
#  array([173, 189, 434, 450], dtype=int64),
#  array([182, 199, 442, 458], dtype=int64),
#  array([203, 219, 466, 482], dtype=int64),
#  array([112, 128, 376, 392], dtype=int64),
#  array([66, 82], dtype=int64),
#  array([ 70,  86, 330, 346], dtype=int64),
#  array([175, 191, 433, 448], dtype=int64),
#  array([ 91, 107, 349, 365], dtype=int64),
#  array([112, 128], dtype=int64),
#  array([172, 188], dtype=int64),
#  array([ 38,  54, 290], dtype=int64),
#  array([  3, 237, 252], dtype=int64),
#  array([198, 214], dtype=int64),
#  array([163, 180], dtype=int64),
#  array([131, 147], dtype=int64),
#  array([ 98, 114], dtype=int64),
#  array([ 38,  54, 278, 294], dtype=int64),
#  array([171, 187], dtype=int64),
#  array([  1,  17, 240, 256, 480, 496], dtype=int64),
#  array([196, 212], dtype=int64),
#  array([ 32,  48, 272, 288], dtype=int64),
#  array([ 10,  26, 255, 271, 497, 513], dtype=int64),
#  array([174, 190, 416, 432, 661, 677], dtype=int64),
#  array([207, 223, 448, 464], dtype=int64),
#  array([ 75,  91, 313, 329, 551, 567], dtype=int64),
#  array([114, 130, 353, 369, 599, 614], dtype=int64),
#  array([182, 197, 426, 442], dtype=int64),
#  array([191, 206], dtype=int64),
#  array([ 15,  31, 254, 270, 496, 512, 734, 750], dtype=int64),
#  array([190, 206, 428, 444], dtype=int64),
#  array([102, 118], dtype=int64),
#  array([105, 121, 353, 370, 600, 616], dtype=int64),
#  array([185, 201, 434, 449], dtype=int64),
#  array([ 61,  77, 313, 329, 564, 580], dtype=int64),
#  array([181, 198, 435, 451], dtype=int64),
#  array([ 56,  72, 312, 328], dtype=int64),
#  array([34, 49], dtype=int64),
#  array([ 39,  54, 302, 318, 562, 578], dtype=int64),
#  array([135, 151, 398, 414], dtype=int64),
#  array([15], dtype=int64),
#  array([159, 175, 428, 444], dtype=int64),
#  array([158, 174, 423, 439], dtype=int64),
#  array([ 91, 107], dtype=int64),
#  array([138, 154, 398, 414], dtype=int64),
#  array([ 35,  51, 289, 305], dtype=int64),
#  array([ 51,  67, 302, 318], dtype=int64),
#  array([ 50,  66, 306, 322], dtype=int64),
#  array([108, 124, 366], dtype=int64),
#  array([ 12, 270, 286], dtype=int64),
#  array([229, 245], dtype=int64),
#  array([161, 177], dtype=int64),
#  array([ 20,  36, 275, 291], dtype=int64),
#  array([162, 178], dtype=int64),
#  array([100, 116, 350, 365], dtype=int64),
#  array([229, 245], dtype=int64),
#  array([ 18,  34, 263, 279, 507, 523], dtype=int64),
#  array([129, 145, 369, 385], dtype=int64),
#  array([ 48,  64, 285, 301], dtype=int64),
#  array([150, 166], dtype=int64),
#  array([ 53,  69, 287, 303], dtype=int64),
#  array([209, 225], dtype=int64),
#  array([169, 185], dtype=int64),
#  array([150, 166], dtype=int64),
#  array([68, 85], dtype=int64),
#  array([  5,  21, 240, 256], dtype=int64),
#  array([144, 160], dtype=int64),
#  array([19, 35], dtype=int64),
#  array([ 10,  26, 248, 264], dtype=int64),
#  array([140, 156], dtype=int64),
#  array([138, 154, 377, 393], dtype=int64),
#  array([146, 163], dtype=int64),
#  array([104, 120], dtype=int64),
#  array([  3,  19, 252, 268], dtype=int64),
#  array([103, 119, 359, 375], dtype=int64),
#  array([204, 220], dtype=int64),
#  array([ 70,  86, 336], dtype=int64),
#  array([  1, 267, 283, 548, 564], dtype=int64),
#  array([241, 257], dtype=int64),
#  array([237, 253], dtype=int64),
#  array([ 13,  29, 280, 296], dtype=int64),
#  array([118, 134, 391, 407], dtype=int64),
#  array([171, 186], dtype=int64),
#  array([162, 179], dtype=int64),
#  array([ 66,  83, 326, 342], dtype=int64),
#  array([ 36,  52, 298, 314], dtype=int64),
#  array([149, 165], dtype=int64),
#  array([ 60,  76, 311], dtype=int64),
#  array([  4, 242, 258], dtype=int64),
#  array([200, 216], dtype=int64),
#  array([153, 169], dtype=int64),
#  array([74, 91], dtype=int64),
#  array([ 16, 241, 257], dtype=int64),
#  array([179, 195], dtype=int64),
#  array([132, 148], dtype=int64),
#  array([ 93, 109], dtype=int64),
#  array([ 45,  61, 279], dtype=int64),
#  array([  8, 226, 242], dtype=int64),
#  array([183, 199], dtype=int64),
#  array([144, 160], dtype=int64),
#  array([115, 131], dtype=int64),
#  array([ 44,  60, 285, 301], dtype=int64),
#  array([194, 210], dtype=int64),
#  array([ 84, 100, 331, 347], dtype=int64),
#  array([193, 210], dtype=int64),
#  array([ 78,  94, 324, 340], dtype=int64),
#  array([192, 209], dtype=int64),
#  array([ 26,  41, 273, 289], dtype=int64),
#  array([160, 176], dtype=int64),
#  array([68, 84], dtype=int64),
#  array([  5,  21, 247, 263], dtype=int64),
#  array([ 93, 110], dtype=int64),
#  array([83, 99], dtype=int64),
#  array([78, 95], dtype=int64),
#  array([42, 57], dtype=int64),
#  array([ 15, 245, 261], dtype=int64),
#  array([  2, 226, 242], dtype=int64),
#  array([  6,  22, 243, 259], dtype=int64),
#  array([169, 185, 404, 420], dtype=int64),
#  array([208, 224], dtype=int64),
#  array([75, 91], dtype=int64),
#  array([194, 210], dtype=int64),
#  array([143, 159, 379, 395], dtype=int64),
#  array([], dtype=float64),
#  array([104, 120, 342, 357], dtype=int64),
#  array([ 33,  49, 269, 285], dtype=int64),
#  array([ 87, 103, 321, 337], dtype=int64),
#  array([101, 116, 344, 359], dtype=int64),
#  array([ 90, 106, 333, 349], dtype=int64),
#  array([ 10, 238, 254, 484, 500], dtype=int64),
#  array([206, 222], dtype=int64),
#  array([189, 205, 442, 458], dtype=int64),
#  array([  7,  23, 258, 274, 511, 527], dtype=int64),
#  array([186, 203, 436, 452], dtype=int64),
#  array([ 64,  79, 317, 334, 572, 588], dtype=int64),
#  array([178, 194, 431], dtype=int64),
#  array([110, 126, 363, 378, 614, 630], dtype=int64),
#  array([102, 118, 350, 366], dtype=int64),
#  array([ 95, 111, 340, 356], dtype=int64),
#  array([204, 220], dtype=int64),
#  array([132, 148, 375, 390], dtype=int64),
#  array([118, 134, 361, 377], dtype=int64),
#  array([171, 187, 413, 429], dtype=int64),
#  array([ 16, 247, 263], dtype=int64),
#  array([ 77,  93, 321, 337, 563, 579], dtype=int64),
#  array([164, 180, 412, 427], dtype=int64),
#  array([127, 143, 371, 387], dtype=int64),
#  array([180, 196, 433, 449], dtype=int64),
#  array([ 10,  26, 255, 271], dtype=int64),
#  array([ 38,  54, 283, 299, 527, 543, 772, 788], dtype=int64),
#  array([170, 186, 413, 429], dtype=int64),
#  array([117, 133, 362, 378, 606, 622], dtype=int64),
#  array([164, 180, 409, 424, 655, 671], dtype=int64),
#  array([156, 172, 399, 415], dtype=int64),
#  array([114, 130, 355, 371], dtype=int64),
#  array([177, 192, 415, 431], dtype=int64),
#  array([2], dtype=int64),
#  array([128, 144, 363, 379, 598, 613], dtype=int64),
#  array([ 93, 109, 325, 341], dtype=int64),
#  array([131, 147, 364, 380], dtype=int64),
#  array([197, 213], dtype=int64),
#  array([  7,  23, 251, 268], dtype=int64),
#  array([ 71,  87, 332, 348], dtype=int64),
#  array([182, 198], dtype=int64),
#  array([ 44,  60, 300, 315], dtype=int64),
#  array([165, 181], dtype=int64),
#  array([57, 73], dtype=int64),
#  array([56, 72], dtype=int64),
#  array([81, 97], dtype=int64),
#  array([ 99, 115, 368, 384], dtype=int64),
#  array([ 79,  95, 330, 346], dtype=int64),
#  array([ 54,  70, 309, 325], dtype=int64),
#  array([ 97, 113], dtype=int64),
#  array([  3,  19, 264, 280], dtype=int64),
#  array([ 28,  44, 287, 303], dtype=int64),
#  array([ 67,  82, 323, 339], dtype=int64),
#  array([116, 132, 372], dtype=int64),
#  array([  5, 238, 253], dtype=int64),
#  array([137, 153], dtype=int64),
#  array([171, 187, 421, 436], dtype=int64),
#  array([194, 210], dtype=int64),
#  array([129, 145], dtype=int64),
#  array([109, 125, 349, 365], dtype=int64),
#  array([149, 165, 385, 400, 622, 638], dtype=int64),
#  array([177, 193], dtype=int64),
#  array([ 15, 234, 250, 472, 487], dtype=int64),
#  array([ 49,  65, 284, 300], dtype=int64),
#  array([11], dtype=int64),
#  array([98], dtype=int64),
#  array([  3, 235, 251, 481, 497], dtype=int64),
#  array([180, 196, 429, 445], dtype=int64),
#  array([154, 170, 414, 430], dtype=int64),
#  array([137, 153, 400, 416], dtype=int64),
#  array([79, 95], dtype=int64),
#  array([141, 157], dtype=int64),
#  array([174, 189], dtype=int64),
#  array([107, 123, 350], dtype=int64),
#  array([ 10, 233, 248], dtype=int64),
#  array([174, 190], dtype=int64),
#  array([163, 179, 400, 416, 636, 652], dtype=int64),
#  array([177, 193, 413, 429], dtype=int64),
#  array([212, 228, 451, 466], dtype=int64),
#  array([200, 216], dtype=int64),
#  array([219, 236], dtype=int64),
#  array([223, 239], dtype=int64),
#  array([ 38,  54, 282, 298], dtype=int64),
#  array([120, 136], dtype=int64),
#  array([140, 156], dtype=int64),
#  array([  8,  24, 254, 270, 504, 519], dtype=int64),
#  array([108, 124, 351, 367], dtype=int64),
#  array([194, 210, 434, 449], dtype=int64),
#  array([133, 149, 379, 395], dtype=int64),
#  array([173, 189, 421, 437], dtype=int64),
#  array([148, 164, 395, 411], dtype=int64),
#  array([147, 163], dtype=int64),
#  array([ 12,  28, 259, 275], dtype=int64),
#  array([156, 172], dtype=int64),
#  array([ 74,  90, 320, 336], dtype=int64),
#  array([207, 223, 451, 467], dtype=int64),
#  array([156, 172, 400, 416, 647, 663], dtype=int64),
#  array([144, 160, 387, 404], dtype=int64),
#  array([ 72,  88, 313, 329], dtype=int64),
#  array([ 83,  99, 325, 341], dtype=int64),
#  array([153, 169], dtype=int64),
#  array([162, 178, 404, 420], dtype=int64),
#  array([ 84, 100, 323, 339], dtype=int64),
#  array([138, 154], dtype=int64),
#  array([40, 56], dtype=int64),
#  array([148, 165, 385, 401], dtype=int64),
#  array([139, 156, 374, 390, 611, 627], dtype=int64),
#  array([133, 150, 370, 386], dtype=int64),
#  array([78, 94], dtype=int64),
#  array([104, 120, 340, 355], dtype=int64),
#  array([ 96, 112, 333, 349, 568, 584, 803, 818], dtype=int64),
#  array([159, 176, 392, 408], dtype=int64),
#  array([ 25,  41, 257, 273, 487, 502], dtype=int64),
#  array([106, 122, 334, 349], dtype=int64),
#  array([101, 116, 328, 344, 555, 571, 780, 797], dtype=int64),
#  array([183, 199, 409], dtype=int64),
#  array([ 99, 115], dtype=int64),
#  array([188, 204, 412, 428], dtype=int64),
#  array([126, 142], dtype=int64),
#  array([ 95, 111], dtype=int64),
#  array([ 70,  85, 294, 309], dtype=int64),
#  array([121, 198, 214], dtype=int64),
#  array([117, 133, 344, 360], dtype=int64),
#  array([154, 171, 385, 401], dtype=int64),
#  array([200, 215, 430, 446, 662, 677], dtype=int64),
#  array([ 75,  91, 305, 321, 534, 549], dtype=int64),
#  array([186, 202], dtype=int64),
#  array([124, 140, 351, 367], dtype=int64),
#  array([148, 164, 374, 390, 599, 615], dtype=int64),
#  array([54, 70], dtype=int64),
#  array([119, 135], dtype=int64),
#  array([ 89, 104], dtype=int64),
#  array([ 73,  88, 294], dtype=int64),
#  array([  7, 212, 228, 436, 452], dtype=int64),
#  array([ 97, 113, 320, 336], dtype=int64),
#  array([122, 137, 344, 359], dtype=int64),
#  array([ 35, 254, 270, 476, 492, 696, 712], dtype=int64),
#  array([151, 166, 370, 386, 590, 606], dtype=int64),
#  array([139, 155, 359], dtype=int64),
#  array([  6, 207, 224], dtype=int64),
#  array([ 15, 219, 235], dtype=int64),
#  array([ 18,  34, 242, 258], dtype=int64),
#  array([55], dtype=int64),
#  array([40], dtype=int64),
#  array([ 39,  55, 263, 279], dtype=int64),
#  array([163, 179], dtype=int64),
#  array([73, 89], dtype=int64),
#  array([ 33,  49, 262, 278], dtype=int64),
#  array([223, 239], dtype=int64),
#  array([ 72,  88, 313, 329, 554, 570], dtype=int64),
#  array([  9,  24, 244, 261], dtype=int64),
#  array([127, 143], dtype=int64),
#  array([199, 215], dtype=int64),
#  array([135, 151], dtype=int64),
#  array([], dtype=float64),
#  array([20, 36], dtype=int64),
#  array([113, 130, 342], dtype=int64),
#  array([ 75,  91, 300, 316, 525, 541], dtype=int64),
#  array([ 25,  41, 248, 264], dtype=int64),
#  array([ 95, 111, 318, 333], dtype=int64),
#  array([152, 169, 375, 391], dtype=int64),
#  array([  7,  23, 227, 243], dtype=int64),
#  array([  6,  22, 225, 241, 384, 399, 447, 463, 545, 668, 683], dtype=int64),
#  array([199, 215], dtype=int64),
#  array([139, 154], dtype=int64),
#  array([167, 183, 389, 404, 611, 626], dtype=int64),
#  array([3], dtype=int64),
#  array([ 72,  88, 294, 310, 517, 533], dtype=int64),
#  array([], dtype=float64),
#  array([175, 191, 423, 439], dtype=int64),
#  array([176, 192], dtype=int64),
#  array([ 49,  65, 311, 327, 572, 588], dtype=int64),
#  array([147, 163, 394, 410], dtype=int64),
#  array([143, 159, 393, 409], dtype=int64),
#  array([ 58,  74, 331, 347], dtype=int64),
#  array([34, 50], dtype=int64),
#  array([197, 213, 474, 490], dtype=int64),
#  array([ 50,  66, 321, 338, 360, 593, 609], dtype=int64),
#  array([219, 235, 489, 505], dtype=int64),
#  array([220, 236], dtype=int64),
#  array([ 47,  62, 322, 338], dtype=int64),
#  array([202, 218], dtype=int64),
#  array([131, 148, 392, 408], dtype=int64),
#  array([ 84, 100, 346, 362], dtype=int64),
#  array([218, 234], dtype=int64),
#  array([ 54,  70, 337, 354], dtype=int64),
#  array([ 11,  27, 281, 297], dtype=int64),
#  array([ 42,  58, 300, 316], dtype=int64),
#  array([163, 178, 413, 429, 661, 677], dtype=int64),
#  array([113, 129, 357, 373, 599], dtype=int64),
#  array([ 10, 233, 250], dtype=int64),
#  array([83, 99], dtype=int64),
#  array([], dtype=float64),
#  array([ 46,  62, 302, 319], dtype=int64),
#  array([ 93, 109, 349, 365], dtype=int64),
#  array([128, 145], dtype=int64),
#  array([], dtype=float64),
#  array([  2,  18, 249, 265], dtype=int64),
#  array([199, 216, 452, 468], dtype=int64),
#  array([171, 187, 424, 440], dtype=int64),
#  array([176, 192], dtype=int64),
#  array([ 24,  40, 276, 293, 528, 544], dtype=int64),
#  array([207, 223, 457, 473], dtype=int64),
#  array([101, 117, 356, 372], dtype=int64),
#  array([212, 228, 468, 485], dtype=int64),
#  array([146, 162], dtype=int64),
#  array([123, 139, 392, 408], dtype=int64),
#  array([], dtype=float64),
#  array([121, 137], dtype=int64),
#  array([40, 56], dtype=int64),
#  array([60, 75], dtype=int64),
#  array([ 69,  85, 328, 344, 585, 601], dtype=int64),
#  array([219, 235], dtype=int64),
#  array([ 66,  82, 331, 347], dtype=int64),
#  array([209, 225, 472, 487], dtype=int64),
#  array([204, 220], dtype=int64),
#  array([120, 137], dtype=int64),
#  array([152, 168], dtype=int64),
#  array([182, 198], dtype=int64),
#  array([140, 156], dtype=int64),
#  array([ 21,  37, 291, 307], dtype=int64),
#  array([219, 235], dtype=int64),
#  array([113, 129], dtype=int64),
#  array([ 53,  69, 324, 340], dtype=int64),
#  array([142, 158, 413], dtype=int64),
#  array([ 14, 267, 283], dtype=int64),
#  array([48, 64], dtype=int64),
#  array([ 71,  87, 345, 361], dtype=int64),
#  array([125, 141], dtype=int64),
#  array([ 79,  95, 341, 357], dtype=int64),
#  array([199, 215, 464, 480], dtype=int64),
#  array([ 50,  66, 306, 322], dtype=int64),
#  array([], dtype=float64),
#  array([  9,  25, 258, 275], dtype=int64),
#  array([104, 120], dtype=int64),
#  array([126, 142, 375, 391], dtype=int64),
#  array([ 84, 100], dtype=int64),
#  array([212, 228, 263], dtype=int64),
#  array([19, 35], dtype=int64),
#  array([76, 92], dtype=int64),
#  array([63, 80], dtype=int64),
#  array([ 29,  45, 269, 285], dtype=int64),
#  array([  2, 224, 240, 465, 481, 706, 722], dtype=int64),
#  array([ 89, 105, 329, 345], dtype=int64),
#  array([170, 185, 408], dtype=int64),
#  array([ 94, 110, 329, 346], dtype=int64),
#  array([174, 190], dtype=int64),
#  array([184, 200, 418, 433], dtype=int64),
#  array([114, 130, 349, 365], dtype=int64),
#  array([145, 160, 397, 413], dtype=int64),
#  array([ 97, 113, 367, 383], dtype=int64),
#  array([ 12, 243, 259], dtype=int64),
#  array([36, 52], dtype=int64),
#  array([56, 71], dtype=int64),
#  array([ 56,  72, 300, 316], dtype=int64),
#  array([117, 133, 359, 375], dtype=int64),
#  array([170, 186, 416, 432], dtype=int64),
#  array([217, 233, 472, 488], dtype=int64),
#  array([ 17,  32, 274, 290], dtype=int64),
#  array([139, 155], dtype=int64),
#  array([214, 230], dtype=int64),
#  array([188, 204], dtype=int64),
#  array([170, 187], dtype=int64),
#  array([195, 211], dtype=int64),
#  array([167, 184], dtype=int64),
#  array([164, 181], dtype=int64),
#  array([169, 185], dtype=int64),
#  array([ 57,  73, 316, 332], dtype=int64),
#  array([189, 205], dtype=int64),
#  array([ 68,  84, 331, 346], dtype=int64),
#  array([116, 132], dtype=int64),
#  array([ 39,  55, 289], dtype=int64),
#  array([ 13, 247, 263], dtype=int64),
#  array([213, 229], dtype=int64),
#  array([146, 162, 400, 416], dtype=int64),
#  array([108, 125, 366, 382], dtype=int64),
#  array([106, 122], dtype=int64),
#  array([171, 187, 421, 437, 670, 685], dtype=int64),
#  array([157, 173], dtype=int64),
#  array([ 98, 114], dtype=int64),
#  array([219, 235], dtype=int64),
#  array([ 70,  86, 313, 329], dtype=int64),
#  array([178, 194], dtype=int64),
#  array([180, 196], dtype=int64),
#  array([ 89, 105, 330, 346], dtype=int64),
#  array([151, 167], dtype=int64),
#  array([13, 29], dtype=int64),
#  array([159, 175], dtype=int64),
#  array([129, 146], dtype=int64),
#  array([12], dtype=int64),
#  array([157, 173], dtype=int64),
#  array([  6,  22, 251, 267], dtype=int64),
#  array([140, 156], dtype=int64),
#  array([7], dtype=int64),
#  array([ 9, 25], dtype=int64),
#  array([131, 146], dtype=int64),
#  array([122, 138, 371, 387], dtype=int64),
#  array([125, 141, 371, 387], dtype=int64),
#  array([188, 204], dtype=int64),
#  array([  2,  18, 240, 256], dtype=int64),
#  array([ 77,  93, 316], dtype=int64),
#  array([  3, 227, 243], dtype=int64),
#  array([ 56,  72, 290, 306, 527, 543], dtype=int64),
#  array([77], dtype=int64),
#  array([ 63, 206, 222], dtype=int64),
#  array([114, 130, 347, 363], dtype=int64),
#  array([ 77,  93, 304, 319], dtype=int64),
#  array([134, 150, 343], dtype=int64),
#  array([15], dtype=int64),
#  array([ 17,  32, 242, 257], dtype=int64),
#  array([193, 210, 416, 431], dtype=int64),
#  array([200, 216], dtype=int64),
#  array([106, 121, 328], dtype=int64),
#  array([  9, 215, 231, 437, 453], dtype=int64),
#  array([144, 160, 364, 380], dtype=int64),
#  array([192], dtype=int64),
#  array([190], dtype=int64),
#  array([150, 166, 370, 386], dtype=int64),
#  array([1], dtype=int64),
#  array([140, 156], dtype=int64),
#  array([131, 147], dtype=int64),
#  array([137, 153], dtype=int64),
#  array([172, 187], dtype=int64),
#  array([50, 66], dtype=int64),
#  array([ 60,  76, 289, 305, 517, 532], dtype=int64),
#  array([190, 205, 417, 433], dtype=int64),
#  array([73, 89], dtype=int64),
#  array([ 19,  36, 245], dtype=int64),
#  array([73, 89], dtype=int64),
#  array([100, 117], dtype=int64),
#  array([  1,  18,  95, 111], dtype=int64),
#  array([102, 118], dtype=int64),
#  array([ 72,  89, 293, 309], dtype=int64),
#  array([  1,  17, 222, 237], dtype=int64),
#  array([30, 46], dtype=int64),
#  array([ 39,  55, 259, 275], dtype=int64),
#  array([ 85, 101], dtype=int64),
#  array([ 20,  36, 243, 258], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([116, 132], dtype=int64),
#  array([69, 85], dtype=int64),
#  array([51], dtype=int64),
#  array([ 22,  38, 242, 258], dtype=int64),
#  array([ 42, 262, 279, 483], dtype=int64),
#  array([94], dtype=int64),
#  array([136], dtype=int64),
#  array([116], dtype=int64),
#  array([128], dtype=int64),
#  array([178, 194, 397], dtype=int64),
#  array([50], dtype=int64),
#  array([117, 134], dtype=int64),
#  array([ 52, 223, 270], dtype=int64),
#  array([141], dtype=int64),
#  array([122], dtype=int64),
#  array([ 4, 64], dtype=int64),
#  array([193, 208], dtype=int64),
#  array([184, 200], dtype=int64),
#  array([ 80,  96, 295, 311], dtype=int64),
#  array([ 76,  92, 296, 312], dtype=int64),
#  array([ 52,  68, 272, 288, 448], dtype=int64),
#  array([  2,  27,  43, 189, 248, 264], dtype=int64),
#  array([174, 190, 396, 412], dtype=int64),
#  array([ 23, 147, 162, 177, 197, 384, 399, 607, 622], dtype=int64),
#  array([110, 126, 332, 349], dtype=int64),
#  array([103, 119, 143, 325], dtype=int64),
#  array([213, 229], dtype=int64),
#  array([  7,  27, 227, 447], dtype=int64),
#  array([ 63, 238, 283, 299], dtype=int64),
#  array([ 14,  32,  58, 117, 164, 176, 250, 267], dtype=int64),
#  array([ 78,  94, 296, 312], dtype=int64),
#  array([116], dtype=int64),
#  array([], dtype=float64),
#  array([ 50,  66, 267, 283], dtype=int64),
#  array([ 68,  84, 284, 300], dtype=int64),
#  array([  9,  24, 226, 241], dtype=int64),
#  array([ 89, 127], dtype=int64),
#  array([101], dtype=int64),
#  array([104, 119], dtype=int64),
#  array([ 97, 113, 311, 327], dtype=int64),
#  ...]

# %%
# compute the rate for each ecg wave
timespan=2 #ms
rate=[]
for i in lomx:
    if not len(i)==0:
        span=2*(max(i)-min(i))/(len(i)-1)
        rate.append(60000/span)
    else:
        rate.append(0)
# Out:
# C:\Users\Flynn\AppData\Local\Temp\ipykernel_43580\2935347302.py:6: RuntimeWarning: invalid value encountered in longlong_scalars
#   span=2*(max(i)-min(i))/(len(i)-1)

# %%
rate
# Out:
# [0,
#  0,
#  334.5724907063197,
#  328.46715328467155,
#  330.88235294117646,
#  324.9097472924188,
#  326.0869565217391,
#  335.82089552238807,
#  340.90909090909093,
#  1875.0,
#  329.6703296703297,
#  323.74100719424456,
#  1875.0,
#  339.622641509434,
#  339.622641509434,
#  347.4903474903475,
#  347.4903474903475,
#  1875.0,
#  1875.0,
#  338.3458646616541,
#  332.10332103321036,
#  1875.0,
#  329.6703296703297,
#  330.88235294117646,
#  2000.0,
#  340.90909090909093,
#  347.4903474903475,
#  1875.0,
#  348.83720930232556,
#  1875.0,
#  335.82089552238807,
#  1875.0,
#  1875.0,
#  1875.0,
#  323.74100719424456,
#  1875.0,
#  1875.0,
#  327.27272727272725,
#  1875.0,
#  340.90909090909093,
#  242.914979757085,
#  239.0438247011952,
#  235.2941176470588,
#  233.46303501945525,
#  232.5581395348837,
#  233.46303501945525,
#  334.5724907063197,
#  338.3458646616541,
#  338.3458646616541,
#  337.07865168539325,
#  1875.0,
#  332.10332103321036,
#  329.6703296703297,
#  2000.0,
#  337.07865168539325,
#  1875.0,
#  338.3458646616541,
#  343.5114503816794,
#  1875.0,
#  342.20532319391634,
#  347.4903474903475,
#  251.0460251046025,
#  247.93388429752065,
#  1875.0,
#  339.622641509434,
#  2000.0,
#  1875.0,
#  334.5724907063197,
#  2000.0,
#  1875.0,
#  337.07865168539325,
#  2000.0,
#  337.07865168539325,
#  1875.0,
#  1875.0,
#  1875.0,
#  2000.0,
#  2000.0,
#  1875.0,
#  358.5657370517928,
#  2000.0,
#  1875.0,
#  1875.0,
#  346.15384615384613,
#  1875.0,
#  1875.0,
#  1875.0,
#  351.5625,
#  352.94117647058823,
#  354.3307086614173,
#  358.5657370517928,
#  255.31914893617022,
#  247.93388429752065,
#  288.46153846153845,
#  329.6703296703297,
#  232.1083172147002,
#  337.07865168539325,
#  337.07865168539325,
#  335.82089552238807,
#  338.3458646616541,
#  346.15384615384613,
#  1875.0,
#  294.11764705882354,
#  347.4903474903475,
#  857.1428571428571,
#  126.05042016806723,
#  357.14285714285717,
#  364.37246963562757,
#  370.3703703703704,
#  370.3703703703704,
#  354.3307086614173,
#  346.15384615384613,
#  1875.0,
#  346.15384615384613,
#  1875.0,
#  335.82089552238807,
#  344.82758620689657,
#  348.83720930232556,
#  340.90909090909093,
#  335.82089552238807,
#  287.35632183908046,
#  287.90786948176583,
#  1875.0,
#  330.88235294117646,
#  231.66023166023166,
#  232.1083172147002,
#  1875.0,
#  1875.0,
#  0,
#  nan,
#  0,
#  2000.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  343.5114503816794,
#  1875.0,
#  0,
#  1875.0,
#  2000.0,
#  1875.0,
#  339.622641509434,
#  1875.0,
#  1875.0,
#  2000.0,
#  1875.0,
#  335.82089552238807,
#  1875.0,
#  350.1945525291829,
#  123.96694214876032,
#  1875.0,
#  355.7312252964427,
#  307.3770491803279,
#  2000.0,
#  347.4903474903475,
#  342.20532319391634,
#  329.6703296703297,
#  314.6853146853147,
#  306.1224489795918,
#  1875.0,
#  0,
#  1875.0,
#  321.42857142857144,
#  276.24309392265195,
#  322.5806451612903,
#  1875.0,
#  1875.0,
#  319.1489361702128,
#  321.42857142857144,
#  322.5806451612903,
#  1875.0,
#  322.5806451612903,
#  1875.0,
#  323.74100719424456,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  333.3333333333333,
#  337.07865168539325,
#  340.90909090909093,
#  338.3458646616541,
#  287.35632183908046,
#  328.46715328467155,
#  315.7894736842105,
#  281.42589118198873,
#  284.6299810246679,
#  277.77777777777777,
#  319.1489361702128,
#  309.2783505154639,
#  306.1224489795918,
#  305.08474576271186,
#  2000.0,
#  307.1672354948805,
#  305.08474576271186,
#  1875.0,
#  1875.0,
#  312.5,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  nan,
#  2000.0,
#  310.55900621118013,
#  314.4654088050314,
#  354.3307086614173,
#  344.82758620689657,
#  343.5114503816794,
#  342.20532319391634,
#  343.5114503816794,
#  1875.0,
#  324.9097472924188,
#  319.1489361702128,
#  316.9014084507042,
#  275.7352941176471,
#  326.0869565217391,
#  319.1489361702128,
#  1875.0,
#  314.6853146853147,
#  1875.0,
#  318.0212014134276,
#  315.7894736842105,
#  307.1672354948805,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  223.88059701492537,
#  221.4022140221402,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  1875.0,
#  1875.0,
#  2000.0,
#  318.0212014134276,
#  322.5806451612903,
#  328.46715328467155,
#  1875.0,
#  323.74100719424456,
#  1875.0,
#  223.04832713754647,
#  222.22222222222223,
#  1875.0,
#  1875.0,
#  1875.0,
#  327.27272727272725,
#  1875.0,
#  2000.0,
#  1875.0,
#  314.6853146853147,
#  nan,
#  227.27272727272728,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  323.74100719424456,
#  1875.0,
#  1875.0,
#  285.7142857142857,
#  nan,
#  224.7191011235955,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  2000.0,
#  290.3225806451613,
#  320.2846975088968,
#  337.07865168539325,
#  384.61538461538464,
#  132.15859030837004,
#  252.10084033613447,
#  360.0,
#  361.4457831325301,
#  317.1247357293869,
#  368.8524590163935,
#  370.3703703703704,
#  361.4457831325301,
#  358.5657370517928,
#  308.0082135523614,
#  355.7312252964427,
#  287.90786948176583,
#  1875.0,
#  327.27272727272725,
#  1875.0,
#  323.74100719424456,
#  380.95238095238096,
#  300.0,
#  342.20532319391634,
#  244.39918533604887,
#  1875.0,
#  355.7312252964427,
#  1875.0,
#  344.82758620689657,
#  1875.0,
#  342.20532319391634,
#  1875.0,
#  321.42857142857144,
#  329.6703296703297,
#  1875.0,
#  332.10332103321036,
#  1875.0,
#  338.3458646616541,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  nan,
#  1875.0,
#  1875.0,
#  1875.0,
#  327.27272727272725,
#  1764.7058823529412,
#  1875.0,
#  319.1489361702128,
#  1875.0,
#  320.2846975088968,
#  314.6853146853147,
#  323.74100719424456,
#  0,
#  322.5806451612903,
#  319.1489361702128,
#  205.4794520547945,
#  216.60649819494586,
#  315.7894736842105,
#  310.34482758620686,
#  1875.0,
#  323.74100719424456,
#  322.5806451612903,
#  1875.0,
#  326.0869565217391,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  218.97810218978103,
#  116.73151750972762,
#  221.4022140221402,
#  1875.0,
#  2000.0,
#  1875.0,
#  1875.0,
#  324.9097472924188,
#  2000.0,
#  240.96385542168676,
#  350.1945525291829,
#  2000.0,
#  0,
#  357.14285714285717,
#  360.0,
#  358.5657370517928,
#  360.0,
#  358.5657370517928,
#  1875.0,
#  315.7894736842105,
#  1875.0,
#  310.34482758620686,
#  295.08196721311475,
#  289.3890675241157,
#  2000.0,
#  302.013422818792,
#  260.4166666666667,
#  1764.7058823529412,
#  306.1224489795918,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  215.8273381294964,
#  212.01413427561837,
#  1875.0,
#  1875.0,
#  218.1818181818182,
#  1875.0,
#  1875.0,
#  319.1489361702128,
#  1764.7058823529412,
#  1875.0,
#  322.5806451612903,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  223.04832713754647,
#  117.6470588235294,
#  223.04832713754647,
#  1875.0,
#  2000.0,
#  1875.0,
#  2000.0,
#  2000.0,
#  310.34482758620686,
#  1875.0,
#  337.07865168539325,
#  1875.0,
#  1875.0,
#  1875.0,
#  248.96265560165975,
#  247.93388429752065,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  338.3458646616541,
#  1875.0,
#  326.0869565217391,
#  1875.0,
#  1875.0,
#  1875.0,
#  333.3333333333333,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  332.10332103321036,
#  240.0,
#  347.4903474903475,
#  1875.0,
#  351.5625,
#  1875.0,
#  347.4903474903475,
#  351.5625,
#  357.14285714285717,
#  358.5657370517928,
#  259.7402597402597,
#  1875.0,
#  361.4457831325301,
#  362.9032258064516,
#  248.96265560165975,
#  246.91358024691357,
#  330.88235294117646,
#  1875.0,
#  311.4186851211073,
#  1875.0,
#  333.3333333333333,
#  225.5639097744361,
#  226.41509433962264,
#  327.27272727272725,
#  328.46715328467155,
#  1875.0,
#  1875.0,
#  314.6853146853147,
#  281.9548872180451,
#  329.6703296703297,
#  326.0869565217391,
#  278.8104089219331,
#  1875.0,
#  318.0212014134276,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  0,
#  0,
#  315.7894736842105,
#  307.1672354948805,
#  1875.0,
#  315.7894736842105,
#  1764.7058823529412,
#  334.5724907063197,
#  1875.0,
#  1875.0,
#  235.2941176470588,
#  235.2941176470588,
#  1875.0,
#  337.07865168539325,
#  337.07865168539325,
#  337.07865168539325,
#  324.9097472924188,
#  322.5806451612903,
#  1875.0,
#  318.0212014134276,
#  1875.0,
#  0,
#  319.1489361702128,
#  0,
#  314.6853146853147,
#  315.7894736842105,
#  2000.0,
#  295.2755905511811,
#  342.20532319391634,
#  1875.0,
#  344.82758620689657,
#  1875.0,
#  334.5724907063197,
#  1875.0,
#  324.9097472924188,
#  326.0869565217391,
#  322.5806451612903,
#  321.42857142857144,
#  1875.0,
#  326.0869565217391,
#  329.6703296703297,
#  328.46715328467155,
#  1875.0,
#  1875.0,
#  238.0952380952381,
#  240.96385542168676,
#  1875.0,
#  1764.7058823529412,
#  1875.0,
#  1875.0,
#  351.5625,
#  1875.0,
#  303.030303030303,
#  1875.0,
#  351.5625,
#  298.2107355864811,
#  298.2107355864811,
#  350.1945525291829,
#  304.8780487804878,
#  300.0,
#  346.15384615384613,
#  2000.0,
#  285.7142857142857,
#  354.3307086614173,
#  1875.0,
#  293.5420743639922,
#  340.90909090909093,
#  289.01734104046244,
#  333.3333333333333,
#  330.88235294117646,
#  2000.0,
#  278.2931354359926,
#  322.5806451612903,
#  nan,
#  315.7894736842105,
#  320.2846975088968,
#  1875.0,
#  326.0869565217391,
#  333.3333333333333,
#  337.07865168539325,
#  330.88235294117646,
#  232.5581395348837,
#  218.97810218978103,
#  1875.0,
#  1875.0,
#  332.10332103321036,
#  1875.0,
#  339.622641509434,
#  1875.0,
#  297.029702970297,
#  351.5625,
#  355.7312252964427,
#  1875.0,
#  360.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  358.5657370517928,
#  1875.0,
#  1875.0,
#  354.3307086614173,
#  1875.0,
#  352.94117647058823,
#  1764.7058823529412,
#  1875.0,
#  339.622641509434,
#  330.88235294117646,
#  1875.0,
#  225.5639097744361,
#  213.14387211367674,
#  1875.0,
#  1875.0,
#  318.0212014134276,
#  311.4186851211073,
#  2000.0,
#  1764.7058823529412,
#  326.0869565217391,
#  323.74100719424456,
#  1875.0,
#  239.0438247011952,
#  236.2204724409449,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  248.96265560165975,
#  1875.0,
#  1875.0,
#  1875.0,
#  256.4102564102564,
#  256.4102564102564,
#  1875.0,
#  1875.0,
#  1875.0,
#  350.1945525291829,
#  1875.0,
#  342.20532319391634,
#  1764.7058823529412,
#  343.5114503816794,
#  1764.7058823529412,
#  342.20532319391634,
#  1875.0,
#  1875.0,
#  348.83720930232556,
#  1764.7058823529412,
#  1875.0,
#  1764.7058823529412,
#  2000.0,
#  243.90243902439025,
#  250.0,
#  355.7312252964427,
#  358.5657370517928,
#  1875.0,
#  1875.0,
#  1875.0,
#  357.14285714285717,
#  0,
#  355.7312252964427,
#  357.14285714285717,
#  360.0,
#  348.83720930232556,
#  347.4903474903475,
#  244.89795918367346,
#  1875.0,
#  334.5724907063197,
#  288.46153846153845,
#  338.3458646616541,
#  286.25954198473283,
#  237.15415019762847,
#  288.46153846153845,
#  340.90909090909093,
#  344.82758620689657,
#  1875.0,
#  348.83720930232556,
#  347.4903474903475,
#  348.83720930232556,
#  242.914979757085,
#  298.804780876494,
#  342.20532319391634,
#  346.15384615384613,
#  334.5724907063197,
#  344.82758620689657,
#  280.0,
#  347.4903474903475,
#  297.029702970297,
#  295.85798816568047,
#  347.4903474903475,
#  350.1945525291829,
#  354.3307086614173,
#  nan,
#  309.2783505154639,
#  362.9032258064516,
#  361.4457831325301,
#  1875.0,
#  344.82758620689657,
#  324.9097472924188,
#  1875.0,
#  332.10332103321036,
#  1875.0,
#  1875.0,
#  1875.0,
#  1875.0,
#  315.7894736842105,
#  337.07865168539325,
#  332.10332103321036,
#  1875.0,
#  324.9097472924188,
#  327.27272727272725,
#  330.88235294117646,
#  234.375,
#  241.93548387096774,
#  1875.0,
#  339.622641509434,
#  1875.0,
#  1875.0,
#  351.5625,
#  306.7484662576687,
#  1875.0,
#  254.23728813559322,
#  358.5657370517928,
#  nan,
#  nan,
#  242.914979757085,
#  339.622641509434,
#  326.0869565217391,
#  322.5806451612903,
#  1875.0,
#  1875.0,
#  2000.0,
#  246.91358024691357,
#  252.10084033613447,
#  1875.0,
#  306.7484662576687,
#  357.14285714285717,
#  354.3307086614173,
#  1875.0,
#  1764.7058823529412,
#  1875.0,
#  346.15384615384613,
#  1875.0,
#  1875.0,
#  293.5420743639922,
#  347.4903474903475,
#  352.94117647058823,
#  343.5114503816794,
#  340.90909090909093,
#  342.20532319391634,
#  1875.0,
#  342.20532319391634,
#  1875.0,
#  343.5114503816794,
#  346.15384615384613,
#  295.85798816568047,
#  346.15384615384613,
#  350.1945525291829,
#  348.83720930232556,
#  1875.0,
#  348.83720930232556,
#  352.94117647058823,
#  1875.0,
#  1875.0,
#  355.7312252964427,
#  307.3770491803279,
#  355.7312252964427,
#  1875.0,
#  358.5657370517928,
#  290.85872576177286,
#  361.4457831325301,
#  314.4654088050314,
#  370.3703703703704,
#  301.7241379310345,
#  265.4867256637168,
#  1875.0,
#  375.0,
#  1875.0,
#  1875.0,
#  376.56903765690373,
#  645.1612903225806,
#  370.3703703703704,
#  364.37246963562757,
#  314.4654088050314,
#  316.45569620253167,
#  1875.0,
#  370.3703703703704,
#  321.19914346895075,
#  1875.0,
#  1875.0,
#  2000.0,
#  271.49321266968326,
#  269.6629213483146,
#  376.56903765690373,
#  379.746835443038,
#  265.87887740029544,
#  329.6703296703297,
#  272.72727272727275,
#  275.22935779816515,
#  272.72727272727275,
#  375.0,
#  nan,
#  nan,
#  375.0,
#  1875.0,
#  1875.0,
#  367.3469387755102,
#  1875.0,
#  301.20481927710847,
#  357.14285714285717,
#  1875.0,
#  1875.0,
#  1875.0,
#  0,
#  1875.0,
#  262.0087336244541,
#  321.88841201716735,
#  376.56903765690373,
#  378.15126050420173,
#  376.56903765690373,
#  381.3559322033898,
#  443.1314623338257,
#  1875.0,
#  2000.0,
#  326.79738562091507,
#  nan,
#  325.37960954446856,
#  0,
#  340.90909090909093,
#  1875.0,
#  278.2931354359926,
#  342.20532319391634,
#  338.3458646616541,
#  311.4186851211073,
#  1875.0,
#  307.1672354948805,
#  322.00357781753127,
#  314.6853146853147,
#  1875.0,
#  309.2783505154639,
#  1875.0,
#  324.9097472924188,
#  323.74100719424456,
#  1875.0,
#  300.0,
#  314.6853146853147,
#  328.46715328467155,
#  291.8287937743191,
#  246.91358024691357,
#  250.0,
#  1875.0,
#  0,
#  329.6703296703297,
#  330.88235294117646,
#  1764.7058823529412,
#  0,
#  342.20532319391634,
#  334.5724907063197,
#  334.5724907063197,
#  1875.0,
#  288.46153846153845,
#  338.3458646616541,
#  332.10332103321036,
#  329.6703296703297,
#  1875.0,
#  315.7894736842105,
#  0,
#  1875.0,
#  1875.0,
#  2000.0,
#  281.9548872180451,
#  1875.0,
#  320.2846975088968,
#  323.74100719424456,
#  1875.0,
#  1764.7058823529412,
#  1875.0,
#  1875.0,
#  1875.0,
#  314.6853146853147,
#  1875.0,
#  1875.0,
#  313.588850174216,
#  221.4022140221402,
#  223.04832713754647,
#  1875.0,
#  310.34482758620686,
#  1875.0,
#  323.74100719424456,
#  320.2846975088968,
#  330.88235294117646,
#  0,
#  338.3458646616541,
#  1875.0,
#  339.622641509434,
#  1875.0,
#  1176.4705882352941,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  351.5625,
#  250.0,
#  351.5625,
#  252.10084033613447,
#  357.14285714285717,
#  1875.0,
#  361.4457831325301,
#  358.5657370517928,
#  335.82089552238807,
#  314.6853146853147,
#  242.914979757085,
#  1875.0,
#  2000.0,
#  346.15384615384613,
#  348.83720930232556,
#  343.5114503816794,
#  332.10332103321036,
#  329.6703296703297,
#  1875.0,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  1875.0,
#  1764.7058823529412,
#  1764.7058823529412,
#  1875.0,
#  327.27272727272725,
#  1875.0,
#  323.74100719424456,
#  1875.0,
#  240.0,
#  240.0,
#  1875.0,
#  333.3333333333333,
#  328.46715328467155,
#  1875.0,
#  291.8287937743191,
#  1875.0,
#  1875.0,
#  1875.0,
#  347.4903474903475,
#  1875.0,
#  1875.0,
#  350.1945525291829,
#  1875.0,
#  1875.0,
#  1875.0,
#  1764.7058823529412,
#  nan,
#  1875.0,
#  344.82758620689657,
#  1875.0,
#  nan,
#  1875.0,
#  2000.0,
#  339.622641509434,
#  343.5114503816794,
#  1875.0,
#  354.3307086614173,
#  251.0460251046025,
#  250.0,
#  308.0082135523614,
#  nan,
#  377.35849056603774,
#  361.4457831325301,
#  371.900826446281,
#  287.08133971291863,
#  nan,
#  375.0,
#  378.15126050420173,
#  1875.0,
#  270.27027027027026,
#  270.27027027027026,
#  381.3559322033898,
#  nan,
#  nan,
#  381.3559322033898,
#  nan,
#  1875.0,
#  1875.0,
#  1875.0,
#  2000.0,
#  1875.0,
#  317.7966101694915,
#  370.3703703703704,
#  1875.0,
#  265.4867256637168,
#  1875.0,
#  1764.7058823529412,
#  818.1818181818182,
#  1875.0,
#  379.746835443038,
#  381.3559322033898,
#  1875.0,
#  381.3559322033898,
#  1875.0,
#  378.15126050420173,
#  0,
#  0,
#  1875.0,
#  1875.0,
#  nan,
#  381.3559322033898,
#  204.08163265306123,
#  nan,
#  nan,
#  nan,
#  nan,
#  273.972602739726,
#  nan,
#  1764.7058823529412,
#  275.22935779816515,
#  nan,
#  nan,
#  500.0,
#  2000.0,
#  1875.0,
#  389.61038961038963,
#  381.3559322033898,
#  303.030303030303,
#  572.5190839694657,
#  378.15126050420173,
#  400.6677796327212,
#  376.56903765690373,
#  405.4054054054054,
#  1875.0,
#  204.54545454545456,
#  381.3559322033898,
#  830.0395256916995,
#  384.61538461538464,
#  nan,
#  0,
#  386.26609442060084,
#  387.93103448275866,
#  387.93103448275866,
#  789.4736842105264,
#  nan,
#  2000.0,
#  391.30434782608694,
#  ...]

# %%
arr = np.nan_to_num(rate)
arr
# Out:
# array([  0.        ,   0.        , 334.57249071, ..., 231.66023166,
#        333.33333333,   0.        ])

# %%
nanlist=[]
for i in range(len(arr)):
    if arr[i]<70 or arr[i]>190:
        nanlist.append(i)

# %%
finalrate=[]
j=0
for i in range(len(arr)):
    if j==len(nanlist):
        break
    if i==nanlist[j]:
        j+=1
        pass
    else:
        finalrate.append(arr[i])

# %%
len(finalrate)
# Out:
# 80

# %%
finalresp=[]
j=0
for i in range(len(x_resp_flow)):
    if j==len(nanlist):
        break
    if i==nanlist[j]:
        j+=1
        pass
    else:
        finalresp.append(x_resp_flow[i])

# %%
# remove incomplete ecg data for resp and ecg wave
fffflow=[]
fffffff=np.array(finalresp)
ttttttt=[]
# Out:
# C:\Users\Flynn\AppData\Local\Temp\ipykernel_43580\2354145880.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   fffffff=np.array(finalresp)

# %%
for i in fffffff:
    i=np.array(i)
    res=processing.resample_sig(i,fs=500,fs_target=(200000/len(i)))
    vbcx=res[0]
    ttttttt.append(res[1])
    fffflow.append(vbcx)

# %%
import pandas as pd

# %%
for i in fffflow:
    i=i[0:399]
for j in ttttttt:
    j=j[0:399]

# %%
len(fffflow)
# Out:
# 80

# %%
import csv

with open("test_02.csv","w", newline="") as csvfile: 
    writer = csv.writer(csvfile)
    writer.writerows(fffflow)
    writer.writerows(ttttttt)

# %%
for i in finalrate:
    print(i)
# Out:
# 126.05042016806723
# 123.96694214876032
# 132.15859030837004
# 116.73151750972762
# 117.6470588235294
# 162.16216216216216
# 144.92753623188406
# 189.4736842105263
# 138.88888888888889
# 140.18691588785046
# 138.24884792626727
# 130.43478260869566
# 139.53488372093022
# 123.96694214876032
# 139.53488372093022
# 138.24884792626727
# 144.92753623188406
# 159.5744680851064
# 147.7832512315271
# 145.63106796116506
# 166.66666666666666
# 150.0
# 154.63917525773195
# 153.0612244897959
# 151.5151515151515
# 135.13513513513513
# 125.52301255230125
# 167.28624535315984
# 122.95081967213115
# 139.53488372093022
# 138.88888888888889
# 138.24884792626727
# 130.43478260869566
# 128.2051282051282
# 132.15859030837004
# 136.986301369863
# 136.986301369863
# 138.88888888888889
# 189.873417721519
# 132.7433628318584
# 125.52301255230125
# 135.13513513513513
# 140.8450704225352
# 125.0
# 135.13513513513513
# 137.61467889908258
# 180.36072144288576
# 126.58227848101266
# 148.5148514851485
# 149.2537313432836
# 153.0612244897959
# 154.63917525773195
# 145.63106796116506
# 166.66666666666666
# 142.18009478672985
# 135.74660633484163
# 119.5219123505976
# 127.38853503184713
# 133.92857142857142
# 131.57894736842104
# 126.05042016806723
# 126.05042016806723
# 133.92857142857142
# 133.33333333333334
# 133.92857142857142
# 129.87012987012986
# 135.74660633484163
# 136.986301369863
# 138.24884792626727
# 137.61467889908258
# 188.08777429467085
# 127.11864406779661
# 129.87012987012986
# 128.2051282051282
# 131.57894736842104
# 131.57894736842104
# 124.22360248447205
# 134.2281879194631
# 182.55578093306286
# 182.55578093306286

# %%
#import numpy as np
#import pandas as pd
#import glob
#import re
#csv_list = glob.glob('*.csv')
#print('发现%s个CSV文件'% len(csv_list))
#print('对文件进行处理中')
#for i in csv_list:
#    fr = open(i,'r',encoding='utf-8').read()
#    with open('合并之后的文件.csv','a',encoding='utf-8') as f:
#        f.write(fr)
#print('所有文件合并完成！')

# %%
freq_lo_ecg = 20
freq_hi_ecg = 125
plt.scatter(time_resp, x_resp, color='#88c999')
x_ecg_filter = bp_filter(x_ecg, fs_ecg, freq_lo_ecg, freq_hi_ecg)
plt.xlabel("TIME STAMP")
plt.ylabel("Signal")
plt.scatter(time_ecg, x_ecg_filter, color='green', s=2)
plt.title("Fliter function")
plt.show()
